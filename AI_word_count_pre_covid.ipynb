# %%
import pandas as pd

# %%
filepath = "Resources/pre-covid-test-data.csv"
df = pd.read_csv(filepath, header = None)

# %%
df
# Out:
#                                                       0
# 0     Stitch Fix, Inc. (SFIX) CEO Katrina Lake on Q4...
# 1     Goldman Sachs reshuffles Asia M&A leadership a...
# 2     What We Learned From Amazon's Big Hardware Ann...
# 3     Cerner: A Great Stock To Add To Your Portfolio...
# 4     Johnson & Johnson settles Ohio lawsuits to avo...
# ...                                                 ...
# 9145  This mobile WiFi company is seeing a huge dema...
# 9146  Fox Selling $1.2 Billion In Debt, Follows Disn...
# 9147                        Air Canada: The Long Runway
# 9148  ProPetro Holding (PUMP) Q4 Earnings and Revenu...
# 9149  Xerox drops $34B HP take-over bid amid COVID-1...
#
# [9150 rows x 1 columns]

# %%
Text = ""
for i in df[0]:
    Text = Text+i

# %%
# Text

# %%
# Cleaning text and lower casing all words
for char in '-.,\n':
    Text=Text.replace(char,' ')
Text = Text.lower()
# split returns a list of words delimited by sequences of whitespace (including tabs, newlines, etc, like re's \s) 
word_list = Text.split()

# %%
# Cleaning text and lower casing all words
for i in df[0]:
    Text = i
    for char in '-.,\n':
        Text = Text.replace(char,' ')
Text = Text.lower()
# split returns a list of words delimited by sequences of whitespace (including tabs, newlines, etc, like re's \s) 
word_list = Text.split()

# %%
word_list
# Out:
# ['stitch',
#  'fix',
#  'inc',
#  '(sfix)',
#  'ceo',
#  'katrina',
#  'lake',
#  'on',
#  'q4',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptgoldman',
#  'sachs',
#  'reshuffles',
#  'asia',
#  'm&a',
#  'leadership',
#  'as',
#  'john',
#  'kim',
#  'retires',
#  'memowhat',
#  'we',
#  'learned',
#  'from',
#  "amazon's",
#  'big',
#  'hardware',
#  'announcementscerner:',
#  'a',
#  'great',
#  'stock',
#  'to',
#  'add',
#  'to',
#  'your',
#  'portfolio',
#  'in',
#  '2020johnson',
#  '&',
#  'johnson',
#  'settles',
#  'ohio',
#  'lawsuits',
#  'to',
#  'avoid',
#  'federal',
#  'trial5',
#  'key',
#  'conclusions',
#  'from',
#  'united',
#  "technologies'",
#  'latest',
#  'presentationfoot',
#  'locker:',
#  'worth',
#  'the',
#  'gamblethe',
#  'stock',
#  'market',
#  'dived',
#  'today',
#  'but',
#  'these',
#  '2',
#  'stocks',
#  'blasted',
#  'higherthese',
#  'high',
#  'yield',
#  'stocks',
#  'are',
#  'adding',
#  'to',
#  'their',
#  'appealthis',
#  'high',
#  'yield',
#  'stock',
#  'could',
#  'generate',
#  'massive',
#  'returns',
#  'over',
#  'the',
#  'next',
#  '5',
#  'yearsnew',
#  'oriental',
#  'education',
#  'sees',
#  'recurring',
#  'revenues',
#  'and',
#  'multi',
#  'generational',
#  'demandj&j',
#  'to',
#  'pay',
#  '$20',
#  '4',
#  'million',
#  'to',
#  'settle',
#  'opioid',
#  'lawsuits',
#  'with',
#  'two',
#  'ohio',
#  'countiespharma',
#  'giant',
#  'j&j',
#  'avoids',
#  'opioid',
#  'trial',
#  'in',
#  'ohio',
#  'with',
#  '$10',
#  'million',
#  'settlementbrokerage',
#  'stocks',
#  'plunge',
#  'as',
#  'schwab',
#  'eliminates',
#  'commissionsjohnson',
#  '&',
#  'johnson',
#  'settles',
#  'with',
#  'ohio',
#  'counties',
#  'ahead',
#  'of',
#  'opioid',
#  'trialvisa',
#  'mastercard',
#  'reconsider',
#  'backing',
#  "facebook's",
#  'libra',
#  'report',
#  'saysapple',
#  'looking',
#  'for',
#  'new',
#  'highwhy',
#  'cloud',
#  'computing',
#  'will',
#  'be',
#  'a',
#  'key',
#  'revenue',
#  'driver',
#  'for',
#  'alibabamicron:',
#  'back',
#  'to',
#  'realitythe',
#  'new',
#  'ireland',
#  'fund',
#  'inc',
#  'monthly',
#  'portfolio',
#  'update',
#  'jim',
#  'cramer',
#  'explains',
#  'how',
#  'to',
#  'play',
#  'stocks',
#  'of',
#  "mcdonald's",
#  'chipotle',
#  'going',
#  'into',
#  'the',
#  'fourth',
#  'quartertd',
#  'ameritrade',
#  'joins',
#  'the',
#  'party',
#  'cuts',
#  'commissions',
#  'on',
#  'stocks',
#  'etfs',
#  'and',
#  'options',
#  'tradesvisa',
#  'mastercard',
#  'reportedly',
#  'reconsidering',
#  'support',
#  'for',
#  "facebook's",
#  'libragrocery',
#  'outlet',
#  'holding',
#  'corp',
#  'announces',
#  'secondary',
#  'offering',
#  'of',
#  'shares',
#  'of',
#  'common',
#  'stockgrocery',
#  'outlet',
#  'holding',
#  'corp',
#  'announces',
#  'waiver',
#  'of',
#  'lock',
#  'up',
#  'restrictionsconed',
#  'ceo',
#  'on',
#  'utility',
#  "stocks'",
#  'reaction',
#  'to',
#  'interest',
#  'ratesweak',
#  'oil',
#  'prices',
#  'hit',
#  "exxon's",
#  'third',
#  'quarter',
#  'earnings:',
#  'filingwalmart',
#  'considering',
#  'its',
#  'options',
#  'for',
#  'its',
#  'jetblack',
#  'concierge',
#  'servicevisa',
#  'mastercard',
#  'reconsider',
#  'backing',
#  "facebook's",
#  'libra:',
#  'wsjthe',
#  'wall',
#  'street',
#  'journal:',
#  'major',
#  'backers',
#  'of',
#  'facebook’s',
#  'libra',
#  'may',
#  'be',
#  'getting',
#  'cold',
#  "feetmcdonald's",
#  'buzzkill:',
#  '4',
#  "tradesnvidia's",
#  'gaming',
#  'business',
#  'could',
#  'get',
#  'a',
#  'boost',
#  'this',
#  'fallshockwave',
#  'hits',
#  'brokerage',
#  'firms',
#  'after',
#  'charles',
#  'schwab',
#  'slashes',
#  'commissionsfacebook',
#  'has',
#  'work',
#  'cut',
#  'out',
#  'for',
#  'them',
#  'with',
#  'libra',
#  'blockchain',
#  "capital's",
#  'bogart',
#  'sayswhy',
#  'mark',
#  'zuckerberg',
#  'needs',
#  'to',
#  'control',
#  'facebook',
#  'in',
#  'his',
#  'own',
#  'wordspaypal',
#  '(pypl)',
#  'vs',
#  'square',
#  '(sq):',
#  'which',
#  'fintech',
#  'stock',
#  'is',
#  'a',
#  'better',
#  'buy?delek',
#  'us',
#  'holdings',
#  'to',
#  'participate',
#  'in',
#  'the',
#  'wolfe',
#  'research',
#  'utilities',
#  '&',
#  'energy',
#  'conferencenetflix',
#  'pops',
#  'after',
#  'streaming',
#  'giant',
#  'announces',
#  'new',
#  'ryan',
#  'reynolds',
#  'action',
#  'filmnextcure',
#  'to',
#  'present',
#  'clinical',
#  'data',
#  'from',
#  'nc318',
#  'phase',
#  '1/2',
#  'clinical',
#  'trial',
#  'at',
#  '34th',
#  'annual',
#  'meeting',
#  'of',
#  'sitcbox:',
#  'watch',
#  'out',
#  'for',
#  'a',
#  'microsoft',
#  'takeover',
#  "upsideford's",
#  'new',
#  'joint',
#  'venture',
#  'in',
#  'india',
#  'is',
#  'an',
#  'expensive',
#  'good',
#  'movecanadian',
#  'national',
#  'unveils',
#  'plan',
#  'for',
#  'winter',
#  'operationsjounce',
#  'therapeutics',
#  'to',
#  'present',
#  'two',
#  'posters',
#  'from',
#  'the',
#  'jtx',
#  '4014',
#  'and',
#  'vopratelimab',
#  'programs',
#  'at',
#  'the',
#  'society',
#  'for',
#  'immunotherapy',
#  'of',
#  'cancer’s',
#  '(sitc)',
#  '34th',
#  'annual',
#  "meetinguber's",
#  'app',
#  'overhaul',
#  'distracts',
#  'from',
#  'its',
#  'slow',
#  'revenue',
#  "growthhere's",
#  'why',
#  'anaptysbio',
#  'stock',
#  'fell',
#  'on',
#  'tuesdaybp',
#  '(bp)',
#  'stock',
#  'moves',
#  '0',
#  '76%:',
#  'what',
#  'you',
#  'should',
#  'knowmolina',
#  '(moh)',
#  'stock',
#  'moves',
#  '0',
#  '22%:',
#  'what',
#  'you',
#  'should',
#  'knowallergan',
#  '(agn)',
#  'stock',
#  'moves',
#  '1',
#  '09%:',
#  'what',
#  'you',
#  'should',
#  'knowcosan',
#  '(czz)',
#  'stock',
#  'moves',
#  '0',
#  '4%:',
#  'what',
#  'you',
#  'should',
#  'knowrent',
#  'a',
#  'center',
#  '(rcii)',
#  'gains',
#  'as',
#  'market',
#  'dips:',
#  'what',
#  'you',
#  'should',
#  'knowamyris',
#  'inc',
#  '(amrs)',
#  'ceo',
#  'john',
#  'melo',
#  'on',
#  'q2',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptbed',
#  'bath',
#  '&',
#  'beyond',
#  'inc',
#  '(bbby)',
#  'ceo',
#  'mary',
#  'winston',
#  'on',
#  'q2',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptamazon',
#  'com',
#  'brings',
#  'alexa',
#  'to',
#  'brazil',
#  'kicks',
#  'off',
#  'pre',
#  'orders',
#  'for',
#  'devices4',
#  'reasons',
#  'to',
#  'buy',
#  'gw',
#  'pharmaceuticals3',
#  'stocks',
#  'that',
#  'got',
#  'slammed',
#  'on',
#  'wednesdayapple',
#  'ceo',
#  'tim',
#  'cook',
#  'defends',
#  'daca',
#  'to',
#  'supreme',
#  'courtairbus',
#  'plant',
#  'in',
#  'alabama',
#  'spared',
#  'fallout',
#  'from',
#  'u',
#  's',
#  'tariffs3',
#  'beaten',
#  'down',
#  'natural',
#  'gas',
#  'stocks',
#  'you',
#  'can',
#  'buy',
#  'to',
#  'weather',
#  'a',
#  'recessionresources',
#  'connection',
#  'inc',
#  '(recn)',
#  'ceo',
#  'kate',
#  'duchene',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcriptresources',
#  'connection',
#  'inc',
#  '(recn)',
#  'ceo',
#  'kate',
#  'duchene',
#  'on',
#  'q1',
#  '2020',
#  'earnings',
#  'call',
#  'transcriptuaw',
#  'mulls',
#  'no',
#  'confidence',
#  'vote',
#  'in',
#  'general',
#  'motors',
#  'ceo',
#  'mary',
#  'barrapaychex',
#  'lifts',
#  'its',
#  'full',
#  'year',
#  'outlook',
#  'after',
#  'a',
#  'bouyant',
#  'start',
#  'to',
#  'the',
#  'yearu',
#  's',
#  'panel',
#  'probing',
#  '737',
#  'max',
#  'seeks',
#  'to',
#  'interview',
#  'boeing',
#  'engineer:',
#  'bloombergapple',
#  'faces',
#  'antitrust',
#  'risk',
#  'around',
#  'default',
#  'appsbuy',
#  'coda',
#  'octapus',
#  'group:',
#  'sonar',
#  'imaging',
#  'niche',
#  'leader',
#  'has',
#  'valuelantronix',
#  'to',
#  'celebrate',
#  'grand',
#  'opening',
#  'of',
#  'new',
#  'facility',
#  'in',
#  'indiahuazhu',
#  'hotels:',
#  '1',
#  'little',
#  'known',
#  'china',
#  'tourism',
#  "stockmicrosoft's",
#  '2',
#  'biggest',
#  'announcements',
#  'on',
#  'wednesdayverizon',
#  'focused',
#  'on',
#  '5g',
#  'mobility',
#  'build',
#  'ceo',
#  'vestberg',
#  'saystesla',
#  'hits',
#  '97',
#  '000',
#  'deliveries',
#  'in',
#  'q3',
#  'up',
#  '1',
#  '9%samsung',
#  'pulls',
#  'the',
#  'plug',
#  'on',
#  'chinese',
#  'smartphone',
#  'productionxpresspa',
#  'announces',
#  'results',
#  'of',
#  'annual',
#  'meeting',
#  'of',
#  'stockholdersorganovo',
#  'acknowledges',
#  'receipt',
#  'of',
#  'proposaltroubles',
#  'with',
#  "tesla's",
#  'automated',
#  'parking',
#  'feature',
#  'summon',
#  'safety',
#  'regulatorsgeneral',
#  "motors'",
#  'new',
#  'pickups',
#  'powered',
#  'a',
#  'ford',
#  'beating',
#  'sales',
#  'gaindouglas',
#  'dynamics:',
#  "2019's",
#  'alpha',
#  'could',
#  'persistbuy',
#  'stock',
#  'in',
#  'spice',
#  'and',
#  'food',
#  'giant',
#  'mccormick',
#  'in',
#  'this',
#  'unpredictable',
#  'market:',
#  'jim',
#  'cramertesla',
#  'delivery',
#  'numbers',
#  'fall',
#  'short',
#  'of',
#  "musk's",
#  '100',
#  '000',
#  'targetflorida',
#  'joins',
#  't',
#  'mobile',
#  'sprint',
#  'merger',
#  'settlementas',
#  'regulatory',
#  'scrutiny',
#  'grows',
#  'for',
#  "facebook's",
#  'libra',
#  'partners',
#  'reconsiderthe',
#  'consumer',
#  'trade:',
#  '3',
#  'pickswill',
#  'costco',
#  '(cost)',
#  'continue',
#  'its',
#  'run',
#  'with',
#  'strong',
#  'q4',
#  'earnings?paychex',
#  'ceo',
#  'to',
#  'jim',
#  'cramer:',
#  'small',
#  'business',
#  'hiring',
#  'picked',
#  'up',
#  'in',
#  'september',
#  'despite',
#  'slowdown',
#  'worriespaychex',
#  'inc',
#  '(payx)',
#  'ceo',
#  'martin',
#  'mucci',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcripthuge',
#  'jump',
#  'in',
#  'short',
#  'interest',
#  'for',
#  'restaurant',
#  'brands',
#  'international',
#  'as',
#  'stock',
#  'hits',
#  'potential',
#  'supporttesla',
#  'delivery',
#  'record',
#  'shows',
#  'u',
#  's',
#  'is',
#  'ready',
#  'for',
#  'evs',
#  "loup's",
#  'munster',
#  'saysbed',
#  'bath',
#  '&',
#  'beyond',
#  'shares',
#  'pop',
#  'on',
#  'eps',
#  'beat',
#  'but',
#  'revenues',
#  'still',
#  'fall',
#  'short',
#  'of',
#  'expectationsus',
#  'declares',
#  "'win'",
#  'in',
#  'boeing',
#  'airbus',
#  'subsidy',
#  'dispute',
#  'but',
#  'travelers',
#  'will',
#  'paykroger',
#  'to',
#  'layoff',
#  'several',
#  'store',
#  'employeesapple',
#  'ceo',
#  'opposes',
#  'trump',
#  'supports',
#  'daca',
#  'recipients',
#  'in',
#  'supreme',
#  'courttesla',
#  'deliveries',
#  'miss',
#  'wall',
#  'street',
#  'estimates;',
#  'shares',
#  'fall',
#  '6%gopro',
#  'cuts',
#  'second',
#  'half',
#  'profit',
#  'outlook',
#  'citing',
#  'hero8',
#  'production',
#  'delaybrookfield',
#  'asset',
#  'management',
#  'is',
#  'firing',
#  'on',
#  'all',
#  'cylindersriverview',
#  'bancorp',
#  'announces',
#  'quarterly',
#  'cash',
#  'dividendprestige',
#  'consumer',
#  'healthcare',
#  'inc',
#  'to',
#  'release',
#  'fiscal',
#  '2020',
#  'second',
#  'quarter',
#  'earnings',
#  'resultsamazon',
#  'is',
#  'diving',
#  'headlong',
#  'into',
#  'the',
#  'grocery',
#  'businessgopro',
#  'shares',
#  'plunge',
#  'nearly',
#  '20%',
#  'in',
#  'extended',
#  'trading',
#  'on',
#  'delay',
#  'in',
#  'camera',
#  'shipmentsfranco',
#  'nevada',
#  'corporation',
#  'may',
#  'soon',
#  'shine',
#  'like',
#  'gold:',
#  'a',
#  'base',
#  'case',
#  'to',
#  'buyapple',
#  'employs',
#  '443',
#  'daca',
#  'recipients',
#  'tim',
#  'cook',
#  'is',
#  'taking',
#  'a',
#  'standservicenow',
#  '(now)',
#  'stock',
#  'moves',
#  '1',
#  '31%:',
#  'what',
#  'you',
#  'should',
#  'knowfacial',
#  'recognition',
#  'is',
#  'coming',
#  'to',
#  'hotels',
#  'i',
#  'stayed',
#  'at',
#  "alibaba's",
#  'hotel',
#  'of',
#  'the',
#  'futureaehr',
#  'test',
#  'systems',
#  '(aehr)',
#  'ceo',
#  'gayn',
#  'erickson',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcriptfacebook',
#  'removes',
#  "'coordinated'",
#  'fake',
#  'accounts',
#  'in',
#  'uae',
#  'egypt',
#  'nigeria',
#  'and',
#  'indonesiasmart',
#  'global',
#  'holdings',
#  'inc',
#  '(sgh)',
#  'ceo',
#  'ajay',
#  'shah',
#  'on',
#  'q4',
#  '2019',
#  'earnings',
#  'call',
#  'transcriptshould',
#  'you',
#  'buy',
#  'this',
#  'battered',
#  'booze',
#  'and',
#  'marijuana',
#  'stock?ascena',
#  'retail',
#  'group',
#  'inc',
#  '(asna)',
#  'ceo',
#  'gary',
#  'muto',
#  'on',
#  'q4',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptalways',
#  'on',
#  'apple',
#  'watch',
#  'series',
#  '5',
#  ...]

# %%
from collections import Counter
Counter(word_list).most_common()
# Out:
# [('on', 2537),
#  ('earnings', 2381),
#  ('ceo', 2148),
#  ('call', 1977),
#  ('results', 1951),
#  ('to', 1944),
#  ('2019', 1694),
#  ('in', 1239),
#  ('inc', 1236),
#  ('the', 1144),
#  ('q4', 984),
#  ('of', 981),
#  ('q3', 922),
#  ('a', 877),
#  ('and', 840),
#  ('for', 839),
#  ('stock', 753),
#  ('is', 649),
#  ('2020', 466),
#  ('with', 390),
#  ('stocks', 379),
#  ('as', 355),
#  ('new', 333),
#  ('its', 330),
#  ('should', 314),
#  ('you', 313),
#  ('buy', 280),
#  ('coronavirus', 279),
#  ('what', 277),
#  ('corporation', 268),
#  ('from', 245),
#  ('at', 238),
#  ('announces', 227),
#  ('it', 220),
#  ('last', 215),
#  ('says', 211),
#  ('market', 203),
#  ('up', 198),
#  ('will', 195),
#  ('after', 190),
#  ('this', 181),
#  ('be', 179),
#  ('down', 178),
#  ('since', 163),
#  ('&', 162),
#  ('s', 162),
#  ('can', 158),
#  ('company', 154),
#  ('are', 152),
#  ('growth', 149),
#  ('shares', 145),
#  ('q1', 143),
#  ('group', 142),
#  ('over', 141),
#  ('dividend', 136),
#  ('holdings', 135),
#  ('q2', 135),
#  ('that', 134),
#  ('3', 133),
#  ('top', 133),
#  ('by', 132),
#  ('moves', 130),
#  ('more', 130),
#  ('could', 126),
#  ('but', 120),
#  ('million', 117),
#  ('corp', 116),
#  ('an', 114),
#  ('0', 112),
#  ('energy', 111),
#  ('5', 110),
#  ('has', 105),
#  ('investors', 101),
#  ('billion', 101),
#  ('out', 100),
#  ('u', 100),
#  ('time', 97),
#  ('than', 95),
#  ('amazon', 94),
#  ('737', 93),
#  ('high', 92),
#  ('about', 92),
#  ('into', 91),
#  ('etfs', 89),
#  ('year', 89),
#  ('why', 88),
#  ('2', 87),
#  ('revenue', 87),
#  ('max', 87),
#  ('business', 86),
#  ('amid', 84),
#  ('big', 82),
#  ('china', 82),
#  ('all', 82),
#  ('report:', 81),
#  ('not', 80),
#  ('covid', 80),
#  ('financial', 79),
#  ('next', 78),
#  ('boeing', 77),
#  ('international', 77),
#  ('apple', 77),
#  ('have', 77),
#  ('tech', 76),
#  ('first', 73),
#  ('management', 72),
#  ('pay', 71),
#  ('therapeutics', 71),
#  ('right', 71),
#  ('value', 70),
#  ('reports', 70),
#  ('sales', 69),
#  ('mark', 68),
#  ('still', 67),
#  ('health', 67),
#  ('due', 66),
#  ('talks', 66),
#  ('pharmaceuticals', 66),
#  ('vs', 65),
#  ('1', 64),
#  ('data', 63),
#  ('strong', 63),
#  ('may', 62),
#  ('deal', 62),
#  ('long', 62),
#  ('offering', 61),
#  ('quarter', 61),
#  ('production', 61),
#  ('price', 61),
#  ('19', 61),
#  ('term', 60),
#  ('tesla', 60),
#  ('jim', 59),
#  ('us', 59),
#  ('david', 59),
#  ('off', 58),
#  ('systems', 58),
#  ('technologies', 58),
#  ('technology', 58),
#  ('these', 57),
#  ('etf', 57),
#  ('gains:', 57),
#  ('best', 57),
#  ('4', 56),
#  ('gains', 56),
#  ('one', 55),
#  ('public', 55),
#  ('ahead', 54),
#  ('000', 54),
#  ('electric', 54),
#  ('investment', 54),
#  ('$1', 54),
#  ('medical', 54),
#  ('yield', 53),
#  ('cash', 53),
#  ('pricing', 53),
#  ('sell', 53),
#  ('your', 52),
#  ('workers', 52),
#  ('buy:', 52),
#  ('capital', 52),
#  ('john', 51),
#  ('cloud', 51),
#  ('how', 51),
#  ('global', 51),
#  ('airlines', 51),
#  ('week', 51),
#  ('just', 51),
#  ('facebook', 50),
#  ('fell', 50),
#  ('oil', 49),
#  ('trade', 49),
#  ('buying', 49),
#  ('home', 49),
#  ('great', 48),
#  ('reasons', 48),
#  ('brands', 48),
#  ('ltd', 47),
#  ('transcriptwhy', 47),
#  ('now', 46),
#  ("'s", 46),
#  ('back', 45),
#  ('mobile', 45),
#  ('against', 45),
#  ('take', 45),
#  ('no', 44),
#  ('employees', 44),
#  ('netflix', 44),
#  ('google', 44),
#  ('report', 43),
#  ('cramer', 43),
#  ('gold', 43),
#  ('wall', 42),
#  ('good', 42),
#  ('bank', 42),
#  ('companies', 42),
#  ('street', 41),
#  ('microsoft', 41),
#  ('short', 41),
#  ('higher', 41),
#  ('during', 41),
#  ('provides', 41),
#  ('key', 40),
#  ('biggest', 40),
#  ('healthcare', 40),
#  ('retail', 40),
#  ('6', 40),
#  ('co', 40),
#  ('stores', 40),
#  ('future', 39),
#  ('plc', 39),
#  ('american', 39),
#  ('michael', 39),
#  ('common', 38),
#  ('hit', 38),
#  ('watch', 38),
#  ('partners', 38),
#  ('despite', 38),
#  ('plans', 38),
#  ('some', 38),
#  ('another', 38),
#  ('steve', 38),
#  ('their', 37),
#  ('better', 37),
#  ('streaming', 37),
#  ('annual', 37),
#  ('7%', 37),
#  ('buys', 37),
#  ('cannabis', 37),
#  ('limited', 37),
#  ('industries', 37),
#  ('two', 36),
#  ('help', 36),
#  ('5%', 36),
#  ('drug', 36),
#  ('reportedly', 35),
#  ('beat', 35),
#  ('7', 35),
#  ('before', 35),
#  ('ceo:', 35),
#  ('gets', 35),
#  ('services', 35),
#  ('make', 35),
#  ('get', 34),
#  ('general', 34),
#  ('record', 34),
#  ('bancorp', 34),
#  ('power', 34),
#  ('2%', 34),
#  ('under', 34),
#  ('10', 34),
#  ('4%', 34),
#  ('acquisition', 34),
#  ('revenues', 33),
#  ('much', 33),
#  ('california', 33),
#  ('expected', 33),
#  ('week:', 33),
#  ('set', 33),
#  ('software', 33),
#  ('low', 33),
#  ('scott', 33),
#  ('cut', 32),
#  ('beyond', 32),
#  ('test', 32),
#  ('close', 32),
#  ('end', 32),
#  ('trust', 32),
#  ('6%', 32),
#  ("it's", 32),
#  ('jumped', 32),
#  ('senior', 32),
#  ('even', 32),
#  ('—', 32),
#  ('holiday', 32),
#  ('jeff', 32),
#  ('transcriptthe', 32),
#  ('prices', 31),
#  ('asset', 31),
#  ('beats', 31),
#  ('solid', 31),
#  ('day', 31),
#  ('york', 31),
#  ('johnson', 30),
#  ('third', 30),
#  ('work', 30),
#  ('plan', 30),
#  ('5g', 30),
#  ('other', 30),
#  ('sinks', 30),
#  ('through', 30),
#  ('popped', 30),
#  ('pharma', 30),
#  ('analyst', 30),
#  ('3%', 30),
#  ('or', 30),
#  ('board', 30),
#  ('launch', 30),
#  ('e', 30),
#  ('contract', 30),
#  ('profit', 29),
#  ('quarterly', 29),
#  ('free', 29),
#  ('target', 29),
#  ('go', 29),
#  ('most', 29),
#  ('if', 29),
#  ('preview:', 29),
#  ('disney', 29),
#  ('things', 29),
#  ('positive', 29),
#  ('fda', 29),
#  ('mike', 29),
#  ('worth', 28),
#  ('delivery', 28),
#  ('small', 28),
#  ('potential', 28),
#  ('store', 28),
#  ('like', 28),
#  ('realty', 28),
#  ('8%', 28),
#  ('income', 28),
#  ('offer', 28),
#  ('continues', 28),
#  ('bill', 28),
#  ('demand', 28),
#  ('report?why', 28),
#  ('latest', 27),
#  ('sees', 27),
#  ('looking', 27),
#  ('update', 27),
#  ('earnings:', 27),
#  ('unveils', 27),
#  ('tim', 27),
#  ('merger', 27),
#  ('online', 27),
#  ('auto', 27),
#  ('media', 27),
#  ('11', 27),
#  ('cuts', 26),
#  ('hits', 26),
#  ('com', 26),
#  ('i', 26),
#  ('looks', 26),
#  ('lags', 26),
#  ('outpaces', 26),
#  ('chief', 26),
#  ('1%', 26),
#  ('air', 26),
#  ('james', 26),
#  ('yielding', 26),
#  ('incorporated', 26),
#  ('9%', 26),
#  ('weekly:', 26),
#  ('we', 25),
#  ('going', 25),
#  ('fourth', 25),
#  ('which', 25),
#  ('chinese', 25),
#  ('food', 25),
#  ('t', 25),
#  ('car', 25),
#  ('union', 25),
#  ('digital', 25),
#  ('rally', 25),
#  ('products', 25),
#  ('service', 25),
#  ('flight', 25),
#  ('chip', 25),
#  ('tom', 25),
#  ('kevin', 25),
#  ('approval', 25),
#  ('share', 25),
#  ('fund', 24),
#  ('support', 24),
#  ('major', 24),
#  ('own', 24),
#  ('full', 24),
#  ('continue', 24),
#  ('nearly', 24),
#  ('soared', 24),
#  ('way', 24),
#  ('calls', 24),
#  ('need', 24),
#  ('bullish', 24),
#  ('investor', 24),
#  ('makes', 24),
#  ('bet', 24),
#  ('look', 24),
#  ('reach', 24),
#  ('growing', 24),
#  ('uber', 24),
#  ('court', 24),
#  ('model', 24),
#  ('factory', 24),
#  ('momentum', 24),
#  ('cap', 24),
#  ('chris', 24),
#  ('dan', 24),
#  ('resources', 24),
#  ('was', 24),
#  ('portfolio', 23),
#  ('phase', 23),
#  ('outlook', 23),
#  ('marijuana', 23),
#  ('sale', 23),
#  ('know', 23),
#  ('dropped', 23),
#  ('insider', 23),
#  ('near', 23),
#  ('communications', 23),
#  ('properties', 23),
#  ('open', 23),
#  ('brian', 23),
#  ('networks', 23),
#  ('8', 23),
#  ('solutions', 23),
#  ('net', 23),
#  ('biotech', 23),
#  ('20', 23),
#  ('trial', 22),
#  ('holding', 22),
#  ('zuckerberg', 22),
#  ('antitrust', 22),
#  ('market:', 22),
#  ('fall', 22),
#  ('trading', 22),
#  ('9', 22),
#  ('opens', 22),
#  ('iphone', 22),
#  ('see', 22),
#  ('world', 22),
#  ('takes', 22),
#  ('care', 22),
#  ('dollar', 22),
#  ("'", 22),
#  ('guidance', 22),
#  ('keep', 22),
#  ('opportunity', 22),
#  ('robert', 22),
#  ('surge', 22),
#  ('joseph', 22),
#  ('greg', 22),
#  ('warehouse', 22),
#  ("here's", 22),
#  ('rebound?why', 22),
#  ('virus', 22),
#  ('$10', 21),
#  ('faces', 21),
#  ('safety', 21),
#  ('restaurant', 21),
#  ('fiscal', 21),
#  ('pot', 21),
#  ('notes', 21),
#  ('sector', 21),
#  ('gm', 21),
#  ('bob', 21),
#  ('resorts', 21),
#  ('industrial', 21),
#  ('early', 21),
#  ('kong', 21),
#  ('real', 21),
#  ('supply', 21),
#  ('credit', 21),
#  ('finally', 21),
#  ('political', 21),
#  ('l', 21),
#  ('industry', 21),
#  ('peter', 21),
#  ('making', 21),
#  ('paul', 21),
#  ('files', 21),
#  ('conference', 21),
#  ('etf:', 21),
#  ('suspends', 21),
#  ('boost', 20),
#  ('too', 20),
#  ('rival', 20),
#  ('startup', 20),
#  ('closing', 20),
#  ('strike', 20),
#  ('balance', 20),
#  ('warns', 20),
#  ('bid', 20),
#  ('cheap', 20),
#  ('likely', 20),
#  ('point', 20),
#  ('impact', 20),
#  ('huge', 20),
#  ('sciences', 20),
#  ('response', 20),
#  ('investing', 20),
#  ('hong', 20),
#  ('meat', 20),
#  ('does', 20),
#  ('jedi', 20),
#  ('s&p', 20),
#  ('america', 20),
#  ('related', 20),
#  ('suspend', 20),
#  ('journal:', 19),
#  ('getting', 19),
#  ('bath', 19),
#  ('build', 19),
#  ('sprint', 19),
#  ('employee', 19),
#  ('rose', 19),
#  ('acquire', 19),
#  ('stake', 19),
#  ('attractive', 19),
#  ('climbed', 19),
#  ('launches', 19),
#  ('who', 19),
#  ('break', 19),
#  ('ipo', 19),
#  ("won't", 19),
#  ('further', 19),
#  ('tests', 19),
#  ('wins', 19),
#  ('jack', 19),
#  ('george', 19),
#  ('richard', 19),
#  ('500', 19),
#  ('libra', 18),
#  ('national', 18),
#  ('plant', 18),
#  ('around', 18),
#  ("tesla's", 18),
#  ('house', 18),
#  ('wants', 18),
#  ('platform', 18),
#  ('might', 18),
#  ('nasdaq', 18),
#  ('step', 18),
#  ('de', 18),
#  ('seattle', 18),
#  ('12', 18),
#  ('rise', 18),
#  ('$2', 18),
#  ('p', 18),
#  ('prime', 18),
#  ('when', 18),
#  ('face', 18),
#  ('restaurants', 18),
#  ('raises', 18),
#  ('biosciences', 18),
#  ('cybertruck', 18),
#  ('giant', 17),
#  ('transcriptamazon', 17),
#  ('got', 17),
#  ('gas', 17),
#  ('consumer', 17),
#  ('declares', 17),
#  ('half', 17),
#  ('solar', 17),
#  ('they', 17),
#  ('bad', 17),
#  ('use', 17),
#  ('hold', 17),
#  ('plus', 17),
#  ('drops', 17),
#  ('government', 17),
#  ('driving', 17),
#  ('working', 17),
#  ('years', 17),
#  ('consider', 17),
#  ('become', 17),
#  (':', 17),
#  ('markets', 17),
#  ('move', 17),
#  ('closes', 17),
#  ('pacific', 17),
#  ('show', 17),
#  ('rob', 17),
#  ('expect', 17),
#  ('valuation', 17),
#  ('total', 17),
#  ('raise', 17),
#  ('bull', 17),
#  ('tops', 17),
#  ('10%', 17),
#  ('bond', 17),
#  ('buffett', 17),
#  ('transcripttesla', 17),
#  ('avoid', 16),
#  ('federal', 16),
#  ('play', 16),
#  ('gaming', 16),
#  ('research', 16),
#  ('motors', 16),
#  ('risk', 16),
#  ('run', 16),
#  ('ready', 16),
#  ('miss', 16),
#  ('gary', 16),
#  ('part', 16),
#  ('stop', 16),
#  ('announce', 16),
#  ('bargain', 16),
#  ('cost', 16),
#  ('estate', 16),
#  ('rates', 16),
#  ('names', 16),
#  ('backed', 16),
#  ('maker', 16),
#  ('highs', 16),
#  ('operations', 16),
#  ('ad', 16),
#  ('drive', 16),
#  ('enterprises', 16),
#  ('partnership', 16),
#  ('j', 16),
#  ('upside', 16),
#  ('markets:', 16),
#  ('goldman', 16),
#  ('brand', 16),
#  ('information', 16),
#  ('return', 16),
#  ('unit', 16),
#  ('tells', 16),
#  ('musk', 16),
#  ('selling', 16),
#  ('pentagon', 16),
#  ('spending', 16),
#  ('anderson', 16),
#  ('eric', 16),
#  ("corporation's", 16),
#  ('presents', 16),
#  ('entertainment', 16),
#  ('gives', 16),
#  ('berkshire', 16),
#  ('based', 16),
#  ('approves', 16),
#  ('preferred', 16),
#  ('four', 16),
#  ('sachs', 15),
#  ('clinical', 15),
#  ('cook', 15),
#  ('seeks', 15),
#  ('shows', 15),
#  ('second', 15),
#  ('soon', 15),
#  ('case', 15),
#  ('ai', 15),
#  ('$100', 15),
#  ('using', 15),
#  ('say', 15),
#  ('debt', 15),
#  ('listing', 15),
#  ('president', 15),
#  ('do', 15),
#  ('jobs', 15),
#  ('davidson', 15),
#  ('past', 15),
#  ('so', 15),
#  ('state', 15),
#  ('receives', 15),
#  ('must', 15),
#  ('our', 15),
#  ('space', 15),
#  ('double', 15),
#  ('morgan', 15),
#  ('sets', 15),
#  ('nvidia', 15),
#  ('water', 15),
#  ('meet', 15),
#  ('fight', 15),
#  ('keith', 15),
#  ('misses', 15),
#  ('less', 15),
#  ('logistics', 15),
#  ('defense', 15),
#  ('money', 15),
#  ('crisis', 15),
#  ('my', 15),
#  ('post', 15),
#  ('only', 15),
#  ('video', 15),
#  ('lower', 15),
#  ('v', 15),
#  ('dave', 15),
#  ('housing', 15),
#  ('office', 15),
#  ('labs', 15),
#  ('behind', 15),
#  ('worker', 15),
#  ('temporarily', 15),
#  ('add', 14),
#  ('charles', 14),
#  ('takeover', 14),
#  ('app', 14),
#  ('dips:', 14),
#  ('martin', 14),
#  ('trump', 14),
#  ('taking', 14),
#  ('coming', 14),
#  ('transcriptfacebook', 14),
#  ('private', 14),
#  ('estimates', 14),
#  ('gained', 14),
#  ('been', 14),
#  ('volatility', 14),
#  ('13', 14),
#  ('ads', 14),
#  ('disney+', 14),
#  ('insurance', 14),
#  ('executive', 14),
#  ('block', 14),
#  ('game', 14),
#  ('recent', 14),
#  ('agreement', 14),
#  ('softbank', 14),
#  ('expects', 14),
#  ('drop', 14),
#  ('treatment', 14),
#  ('class', 14),
#  ('undervalued', 14),
#  ('depot', 14),
#  ('steps', 14),
#  ('confirms', 14),
#  ('dips', 14),
#  ('broader', 14),
#  ('development', 14),
#  ('pick', 14),
#  ('because', 14),
#  ('transcriptmicrosoft', 14),
#  ('commerce', 14),
#  ('strategy', 14),
#  ('starting', 14),
#  ('property', 14),
#  ('lawsuit', 14),
#  ('december', 14),
#  ('joe', 14),
#  ('fargo', 14),
#  ('shareholder', 14),
#  ('2019why', 14),
#  ('united', 13),
#  ('massive', 13),
#  ('computing', 13),
#  ('meeting', 13),
#  ('orders', 13),
#  ('group:', 13),
#  ('jump', 13),
#  ('marc', 13),
#  ('expands', 13),
#  ('change', 13),
#  ('focus', 13),
#  ('canada', 13),
#  ('energy:', 13),
#  ('invest', 13),
#  ('testing', 13),
#  ('lost', 13),
#  ('parent', 13),
#  ('labor', 13),
#  ('fair', 13),
#  ('here', 13),
#  ('renewable', 13),
#  ("don't", 13),
#  ('fuel', 13),
#  ('banks', 13),
#  ('desk', 13),
#  ('security', 13),
#  ('people', 13),
#  ('starliner', 13),
#  ('news:', 13),
#  ('chairman', 13),
#  ('surged', 13),
#  ('tv', 13),
#  ('times', 13),
#  ('provide', 13),
#  ('win', 13),
#  ('steel', 13),
#  ('below', 13),
#  ('paying', 13),
#  ('signs', 13),
#  ('news', 13),
#  ('offers', 13),
#  ('remains', 13),
#  ('again', 13),
#  ('would', 13),
#  ('travel', 13),
#  ('lp', 13),
#  ('alphabet', 13),
#  ('shipping', 13),
#  ('any', 13),
#  ('loss', 13),
#  ('rich', 13),
#  ('dr', 13),
#  ('card', 13),
#  ('discovery', 13),
#  ('50', 13),
#  ('march', 13),
#  ('flights', 13),
#  ('lake', 12),
#  ("facebook's", 12),
#  ('outlet', 12),
#  ('interest', 12),
#  ('his', 12),
#  ('action', 12),
#  ('start', 12),
#  ('pulls', 12),
#  ('100', 12),
#  ('three', 12),
#  ('live', 12),
#  ('n', 12),
#  ('black', 12),
#  ('really', 12),
#  ('current', 12),
#  ('grants', 12),
#  ('rule', 12),
#  ('decade', 12),
#  ('uaw', 12),
#  ('six', 12),
#  ('fox', 12),
#  ('cutting', 12),
#  ('2020why', 12),
#  ('network', 12),
#  ('reaches', 12),
#  ('worst', 12),
#  ('patent', 12),
#  ('made', 12),
#  ("what's", 12),
#  ('pg&e', 12),
#  ('life', 12),
#  ('cars', 12),
#  ('surpass', 12),
#  ('walmart', 12),
#  ('lead', 12),
#  ('additional', 12),
#  ('stanley', 12),
#  ('sports', 12),
#  ("isn't", 12),
#  ('keeps', 12),
#  ('wework', 12),
#  ('hitting', 12),
#  ('partner', 12),
#  ('battle', 12),
#  ('claims', 12),
#  ('surges', 12),
#  ('myers', 12),
#  ('give', 12),
#  ('delivers', 12),
#  ('bruce', 12),
#  ('line', 12),
#  ('customers', 12),
#  ('while', 12),
#  ('pharmaceutical', 12),
#  ('todd', 12),
#  ('$10b', 12),
#  ('turnaround', 12),
#  ('–', 12),
#  ('building', 12),
#  ('chrysler', 12),
#  ('poised', 12),
#  ('gain', 12),
#  ('aid', 12),
#  ('january', 12),
#  ('warren', 12),
#  ('safe', 12),
#  ('continue?why', 12),
#  ('vaccine', 12),
#  ('fix', 11),
#  ('asia', 11),
#  ("mcdonald's", 11),
#  ('joins', 11),
#  ('india', 11),
#  ('ford', 11),
#  ('trade:', 11),
#  ('grocery', 11),
#  ('series', 11),
#  ('manufacturing', 11),
#  ('rising', 11),
#  ('expansion', 11),
#  ('box', 11),
#  ('remain', 11),
#  ('inducement', 11),
#  ('dip', 11),
#  ('nears', 11),
#  ('lot', 11),
#  ('winning', 11),
#  ('largest', 11),
#  ('diabetes', 11),
#  ('expectations', 11),
#  ('rejects', 11),
#  ('increase', 11),
#  ('fast', 11),
#  ('cancer', 11),
#  ('jay', 11),
#  ('active', 11),
#  ('exec', 11),
#  ('social', 11),
#  ('therapy', 11),
#  ('cola', 11),
#  ("company's", 11),
#  ("apple's", 11),
#  ('five', 11),
#  ('star', 11),
#  ('vehicles', 11),
#  ('tax', 11),
#  ('priced', 11),
#  ('very', 11),
#  ('patrick', 11),
#  ('white', 11),
#  ('holdings:', 11),
#  ('island', 11),
#  ('per', 11),
#  ('green', 11),
#  ('breaks', 11),
#  ('changes', 11),
#  ('dividends', 11),
#  ('van', 11),
#  ('commercial', 11),
#  ('non', 11),
#  ('retailers', 11),
#  ('ever', 11),
#  ('funds', 11),
#  ("china's", 11),
#  ('30', 11),
#  ('canadian', 11),
#  ('takeaways', 11),
#  ('flow', 11),
#  ('jet', 11),
#  ('vehicle', 11),
#  ('gates', 11),
#  ('asks', 11),
#  ("group's", 11),
#  ('relationship', 11),
#  ('many', 11),
#  ('brown', 11),
#  ('posts', 11),
#  ('miller', 11),
#  ('andrew', 11),
#  ('midstream', 11),
#  ('sheet', 11),
#  ('mortgage', 11),
#  ('matt', 11),
#  ('ron', 11),
#  ('pipeline', 11),
#  ('13%', 11),
#  ('pat', 11),
#  ('goes', 11),
#  ('biopharma', 11),
#  ('materials', 11),
#  ('hathaway', 11),
#  ('join', 11),
#  ('super', 11),
#  ('shanghai', 11),
#  ('put', 11),
#  ('leave', 11),
#  ('direct', 11),
#  ('ces', 11),
#  ('777x', 11),
#  ('education', 10),
#  ('fintech', 10),
#  ('leader', 10),
#  ('airbus', 10),
#  ('release', 10),
#  ('20%', 10),
#  ('founder', 10),
#  ('australia', 10),
#  ('canopy', 10),
#  ('falls', 10),
#  ('financing', 10),
#  ('sportswear', 10),
#  ('find', 10),
#  ('smart', 10),
#  ('city', 10),
#  ('15%', 10),
#  ('14%', 10),
#  ('rating', 10),
#  ('coca', 10),
#  ('re', 10),
#  ("world's", 10),
#  ('where', 10),
#  ('dynamics', 10),
#  ('were', 10),
#  ('electronics', 10),
#  ('among', 10),
#  ('order', 10),
#  ('flat', 10),
#  ('force', 10),
#  ('grubhub', 10),
#  ('cfo', 10),
#  ('boeing’s', 10),
#  ('gene', 10),
#  ('nike', 10),
#  ('headwinds', 10),
#  ('turning', 10),
#  ('enters', 10),
#  ('airline', 10),
#  ('52', 10),
#  ('31', 10),
#  ('payments', 10),
#  ('apparel', 10),
#  ('pressure', 10),
#  ('sony', 10),
#  ('economy', 10),
#  ('least', 10),
#  ('transcriptgoogle', 10),
#  ('operating', 10),
#  ...]
