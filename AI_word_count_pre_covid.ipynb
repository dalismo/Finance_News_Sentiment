# %%
import pandas as pd

# %%
# filepath = "Resources/pre-covid-test-data.csv"
# df = pd.read_csv(filepath, header = None)

# %%
filepath = "Resources/pre_covid_sentiments_predictions_headlines_lr_model.csv"
df = pd.read_csv(filepath)

# %%
# df.columns
df.drop(["Unnamed: 0"], axis = 1, inplace = True)
df
# Out:
#      predicted_label                                               text
# 0            Neutral  Stitch Fix, Inc. (SFIX) CEO Katrina Lake on Q4...
# 1            Neutral  Goldman Sachs reshuffles Asia M&A leadership a...
# 2           Positive  What We Learned From Amazon's Big Hardware Ann...
# 3           Positive  Cerner: A Great Stock To Add To Your Portfolio...
# 4            Neutral  Johnson & Johnson settles Ohio lawsuits to avo...
# ...              ...                                                ...
# 9145        Positive  This mobile WiFi company is seeing a huge dema...
# 9146         Neutral  Fox Selling $1.2 Billion In Debt, Follows Disn...
# 9147         Neutral                        Air Canada: The Long Runway
# 9148        Negative  ProPetro Holding (PUMP) Q4 Earnings and Revenu...
# 9149        Negative  Xerox drops $34B HP take-over bid amid COVID-1...
#
# [9150 rows x 2 columns]

# %%
Neutral_Text = ""
Pos_Text = ""
Neg_Text = ""
for index, row in df.iterrows():
#     print(row['predicted_label'])
    if row['predicted_label'] == "Neutral":
        Neutral_Text = Neutral_Text+row['text']
    if row['predicted_label'] == "Positive":
        Pos_Text = Pos_Text+row['text']
    if row['predicted_label'] == "Negative":
        Neg_Text = Neg_Text+row['text']

# %%
# Neutral_Text

# %%
# Cleaning text and lower casing all words
for char in '-.,\n':
    Neutral_Text=Neutral_Text.replace(char,' ')
Neutral_Text = Neutral_Text.lower()
# split returns a list of words delimited by sequences of whitespace (including tabs, newlines, etc, like re's \s) 
word_list_neutral = Neutral_Text.split()

# %%
word_list_neutral
# Out:
# ['stitch',
#  'fix',
#  'inc',
#  '(sfix)',
#  'ceo',
#  'katrina',
#  'lake',
#  'on',
#  'q4',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptgoldman',
#  'sachs',
#  'reshuffles',
#  'asia',
#  'm&a',
#  'leadership',
#  'as',
#  'john',
#  'kim',
#  'retires',
#  'memojohnson',
#  '&',
#  'johnson',
#  'settles',
#  'ohio',
#  'lawsuits',
#  'to',
#  'avoid',
#  'federal',
#  'trial5',
#  'key',
#  'conclusions',
#  'from',
#  'united',
#  "technologies'",
#  'latest',
#  'presentationfoot',
#  'locker:',
#  'worth',
#  'the',
#  'gamblenew',
#  'oriental',
#  'education',
#  'sees',
#  'recurring',
#  'revenues',
#  'and',
#  'multi',
#  'generational',
#  'demandpharma',
#  'giant',
#  'j&j',
#  'avoids',
#  'opioid',
#  'trial',
#  'in',
#  'ohio',
#  'with',
#  '$10',
#  'million',
#  'settlementjohnson',
#  '&',
#  'johnson',
#  'settles',
#  'with',
#  'ohio',
#  'counties',
#  'ahead',
#  'of',
#  'opioid',
#  'trialapple',
#  'looking',
#  'for',
#  'new',
#  'highthe',
#  'new',
#  'ireland',
#  'fund',
#  'inc',
#  'monthly',
#  'portfolio',
#  'update',
#  'visa',
#  'mastercard',
#  'reportedly',
#  'reconsidering',
#  'support',
#  'for',
#  "facebook's",
#  'libragrocery',
#  'outlet',
#  'holding',
#  'corp',
#  'announces',
#  'secondary',
#  'offering',
#  'of',
#  'shares',
#  'of',
#  'common',
#  'stockgrocery',
#  'outlet',
#  'holding',
#  'corp',
#  'announces',
#  'waiver',
#  'of',
#  'lock',
#  'up',
#  'restrictionsconed',
#  'ceo',
#  'on',
#  'utility',
#  "stocks'",
#  'reaction',
#  'to',
#  'interest',
#  'ratesweak',
#  'oil',
#  'prices',
#  'hit',
#  "exxon's",
#  'third',
#  'quarter',
#  'earnings:',
#  'filingvisa',
#  'mastercard',
#  'reconsider',
#  'backing',
#  "facebook's",
#  'libra:',
#  'wsjthe',
#  'wall',
#  'street',
#  'journal:',
#  'major',
#  'backers',
#  'of',
#  'facebook’s',
#  'libra',
#  'may',
#  'be',
#  'getting',
#  'cold',
#  'feetpaypal',
#  '(pypl)',
#  'vs',
#  'square',
#  '(sq):',
#  'which',
#  'fintech',
#  'stock',
#  'is',
#  'a',
#  'better',
#  'buy?delek',
#  'us',
#  'holdings',
#  'to',
#  'participate',
#  'in',
#  'the',
#  'wolfe',
#  'research',
#  'utilities',
#  '&',
#  'energy',
#  'conferencenetflix',
#  'pops',
#  'after',
#  'streaming',
#  'giant',
#  'announces',
#  'new',
#  'ryan',
#  'reynolds',
#  'action',
#  'filmnextcure',
#  'to',
#  'present',
#  'clinical',
#  'data',
#  'from',
#  'nc318',
#  'phase',
#  '1/2',
#  'clinical',
#  'trial',
#  'at',
#  '34th',
#  'annual',
#  'meeting',
#  'of',
#  "sitcford's",
#  'new',
#  'joint',
#  'venture',
#  'in',
#  'india',
#  'is',
#  'an',
#  'expensive',
#  'good',
#  'movecanadian',
#  'national',
#  'unveils',
#  'plan',
#  'for',
#  'winter',
#  'operationsjounce',
#  'therapeutics',
#  'to',
#  'present',
#  'two',
#  'posters',
#  'from',
#  'the',
#  'jtx',
#  '4014',
#  'and',
#  'vopratelimab',
#  'programs',
#  'at',
#  'the',
#  'society',
#  'for',
#  'immunotherapy',
#  'of',
#  'cancer’s',
#  '(sitc)',
#  '34th',
#  'annual',
#  "meetinguber's",
#  'app',
#  'overhaul',
#  'distracts',
#  'from',
#  'its',
#  'slow',
#  'revenue',
#  'growthbp',
#  '(bp)',
#  'stock',
#  'moves',
#  '0',
#  '76%:',
#  'what',
#  'you',
#  'should',
#  'knowmolina',
#  '(moh)',
#  'stock',
#  'moves',
#  '0',
#  '22%:',
#  'what',
#  'you',
#  'should',
#  'knowallergan',
#  '(agn)',
#  'stock',
#  'moves',
#  '1',
#  '09%:',
#  'what',
#  'you',
#  'should',
#  'knowcosan',
#  '(czz)',
#  'stock',
#  'moves',
#  '0',
#  '4%:',
#  'what',
#  'you',
#  'should',
#  'knowamyris',
#  'inc',
#  '(amrs)',
#  'ceo',
#  'john',
#  'melo',
#  'on',
#  'q2',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptbed',
#  'bath',
#  '&',
#  'beyond',
#  'inc',
#  '(bbby)',
#  'ceo',
#  'mary',
#  'winston',
#  'on',
#  'q2',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptamazon',
#  'com',
#  'brings',
#  'alexa',
#  'to',
#  'brazil',
#  'kicks',
#  'off',
#  'pre',
#  'orders',
#  'for',
#  'devicesapple',
#  'ceo',
#  'tim',
#  'cook',
#  'defends',
#  'daca',
#  'to',
#  'supreme',
#  'courtresources',
#  'connection',
#  'inc',
#  '(recn)',
#  'ceo',
#  'kate',
#  'duchene',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcriptresources',
#  'connection',
#  'inc',
#  '(recn)',
#  'ceo',
#  'kate',
#  'duchene',
#  'on',
#  'q1',
#  '2020',
#  'earnings',
#  'call',
#  'transcriptuaw',
#  'mulls',
#  'no',
#  'confidence',
#  'vote',
#  'in',
#  'general',
#  'motors',
#  'ceo',
#  'mary',
#  'barrau',
#  's',
#  'panel',
#  'probing',
#  '737',
#  'max',
#  'seeks',
#  'to',
#  'interview',
#  'boeing',
#  'engineer:',
#  'bloomberglantronix',
#  'to',
#  'celebrate',
#  'grand',
#  'opening',
#  'of',
#  'new',
#  'facility',
#  'in',
#  'indiaxpresspa',
#  'announces',
#  'results',
#  'of',
#  'annual',
#  'meeting',
#  'of',
#  'stockholdersorganovo',
#  'acknowledges',
#  'receipt',
#  'of',
#  'proposaltroubles',
#  'with',
#  "tesla's",
#  'automated',
#  'parking',
#  'feature',
#  'summon',
#  'safety',
#  'regulatorsflorida',
#  'joins',
#  't',
#  'mobile',
#  'sprint',
#  'merger',
#  'settlementas',
#  'regulatory',
#  'scrutiny',
#  'grows',
#  'for',
#  "facebook's",
#  'libra',
#  'partners',
#  'reconsiderpaychex',
#  'inc',
#  '(payx)',
#  'ceo',
#  'martin',
#  'mucci',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcriptus',
#  'declares',
#  "'win'",
#  'in',
#  'boeing',
#  'airbus',
#  'subsidy',
#  'dispute',
#  'but',
#  'travelers',
#  'will',
#  'paykroger',
#  'to',
#  'layoff',
#  'several',
#  'store',
#  'employeesapple',
#  'ceo',
#  'opposes',
#  'trump',
#  'supports',
#  'daca',
#  'recipients',
#  'in',
#  'supreme',
#  'courtbrookfield',
#  'asset',
#  'management',
#  'is',
#  'firing',
#  'on',
#  'all',
#  'cylindersriverview',
#  'bancorp',
#  'announces',
#  'quarterly',
#  'cash',
#  'dividendprestige',
#  'consumer',
#  'healthcare',
#  'inc',
#  'to',
#  'release',
#  'fiscal',
#  '2020',
#  'second',
#  'quarter',
#  'earnings',
#  'resultsservicenow',
#  '(now)',
#  'stock',
#  'moves',
#  '1',
#  '31%:',
#  'what',
#  'you',
#  'should',
#  'knowfacial',
#  'recognition',
#  'is',
#  'coming',
#  'to',
#  'hotels',
#  'i',
#  'stayed',
#  'at',
#  "alibaba's",
#  'hotel',
#  'of',
#  'the',
#  'futureaehr',
#  'test',
#  'systems',
#  '(aehr)',
#  'ceo',
#  'gayn',
#  'erickson',
#  'on',
#  'q1',
#  '2020',
#  'results',
#  'earnings',
#  'call',
#  'transcriptfacebook',
#  'removes',
#  "'coordinated'",
#  'fake',
#  'accounts',
#  'in',
#  'uae',
#  'egypt',
#  'nigeria',
#  'and',
#  'indonesiasmart',
#  'global',
#  'holdings',
#  'inc',
#  '(sgh)',
#  'ceo',
#  'ajay',
#  'shah',
#  'on',
#  'q4',
#  '2019',
#  'earnings',
#  'call',
#  'transcriptascena',
#  'retail',
#  'group',
#  'inc',
#  '(asna)',
#  'ceo',
#  'gary',
#  'muto',
#  'on',
#  'q4',
#  '2019',
#  'results',
#  'earnings',
#  'call',
#  'transcriptalways',
#  'on',
#  'apple',
#  'watch',
#  'series',
#  '5',
#  'helps',
#  'to',
#  'dim',
#  '‘nerd',
#  'factor’u',
#  's',
#  'house',
#  'panel',
#  'wants',
#  "facebook's",
#  'zuckerberg',
#  'to',
#  'testify',
#  'on',
#  'libra',
#  'by',
#  'januaryheron',
#  'therapeutics:',
#  'priming',
#  'the',
#  'fusejohn',
#  'malone',
#  'completes',
#  'sale',
#  'of',
#  'his',
#  'lionsgate',
#  'stakeincoming',
#  'hp',
#  'ceo',
#  'announces',
#  '7',
#  '000',
#  '9',
#  '000',
#  'layoffs',
#  'as',
#  'part',
#  'of',
#  'major',
#  'restructuringhp',
#  'plans',
#  'to',
#  'reduce',
#  'its',
#  'global',
#  'staff',
#  'by',
#  'thousands',
#  'of',
#  'employees',
#  'over',
#  'the',
#  'next',
#  'three',
#  'yearskey',
#  'words:',
#  'mark',
#  'zuckerberg',
#  'on',
#  'billionaires:',
#  '‘at',
#  'some',
#  'level',
#  'no',
#  'one',
#  'deserves',
#  'to',
#  'have',
#  'that',
#  'much',
#  'money’business',
#  'as',
#  'the',
#  'greatest',
#  'platform',
#  'for',
#  'change',
#  'with',
#  'marc',
#  'benioff',
#  '(salesforce)grocery',
#  'outlet',
#  'holding',
#  'corp',
#  'announces',
#  'pricing',
#  'of',
#  'secondary',
#  'offering',
#  'of',
#  'shares',
#  'of',
#  'common',
#  'stockhp',
#  'inc',
#  'to',
#  'cut',
#  'about',
#  '7',
#  '000',
#  'to',
#  '9',
#  '000',
#  "jobsfacebook's",
#  'mark',
#  'zuckerberg',
#  'live',
#  'streams',
#  'employee',
#  'q&a',
#  "'stands",
#  "by'",
#  'comments',
#  'in',
#  'leaked',
#  'recordinghp',
#  'inc',
#  'announces',
#  'fiscal',
#  '2020',
#  'financial',
#  'outlook',
#  '&',
#  'restructuring',
#  'plancabot',
#  'microelectronics',
#  'corporation',
#  'to',
#  'release',
#  'financial',
#  'results',
#  'for',
#  'fourth',
#  'quarter',
#  'and',
#  'full',
#  'fiscal',
#  'year',
#  '2019',
#  'after',
#  'market',
#  'close',
#  'on',
#  'november',
#  '6',
#  '2019nw',
#  'natural',
#  'holdings',
#  'increases',
#  'dividend',
#  'for',
#  '64th',
#  'consecutive',
#  'yeartale',
#  'of',
#  'two',
#  'f',
#  'a',
#  'a',
#  'n',
#  'g',
#  'stocks:',
#  '5',
#  'tradesnovelion',
#  'therapeutics',
#  'announces',
#  'filing',
#  'of',
#  'definitive',
#  'proxy',
#  'statement',
#  'in',
#  'connection',
#  'with',
#  'proposed',
#  'liquidation',
#  'and',
#  'other',
#  'mattersbrandywine',
#  'realty',
#  'trust',
#  'prices',
#  '$100',
#  '0',
#  'million',
#  'of',
#  '4',
#  '100%',
#  'guaranteed',
#  'notes',
#  'due',
#  '2024',
#  'and',
#  '$100',
#  '0',
#  'million',
#  'of',
#  '4',
#  '550%',
#  'guaranteed',
#  'notes',
#  'due',
#  "2029paychex's",
#  'management',
#  'is',
#  'bent',
#  'on',
#  'using',
#  'innovation',
#  'to',
#  'secure',
#  'its',
#  'customer',
#  'basegold',
#  'looks',
#  'shiny',
#  'for',
#  'fourth',
#  'quarter',
#  'say',
#  'expertsgoogle',
#  'ceo',
#  'and',
#  'ivanka',
#  'trump',
#  'announce',
#  'plan',
#  'to',
#  'teach',
#  'workers',
#  'tech',
#  'skillssaia',
#  'opens',
#  'new',
#  'southern',
#  'california',
#  'terminalu',
#  's',
#  'agency',
#  'reviews',
#  'whether',
#  '2',
#  '000',
#  'teslas',
#  'should',
#  'have',
#  'been',
#  'recalled2',
#  'trends',
#  'in',
#  'wind',
#  'power',
#  'that',
#  'investors',
#  'need',
#  'to',
#  'know',
#  'aboutafter',
#  'a',
#  'year',
#  'of',
#  'volatility',
#  'which',
#  'sector',
#  'etfs',
#  'are',
#  'in',
#  'the',
#  'black?the',
#  'mythical',
#  'ipad',
#  'laptop:',
#  'apple’s',
#  'forbidden',
#  'fruitaerocentury',
#  'corp',
#  'announces',
#  'aircraft',
#  'repossessionsbetter',
#  'buy:',
#  'bloom',
#  'energy',
#  'vs',
#  'plug',
#  'powervmware',
#  'and',
#  'carbon',
#  'black',
#  'announce',
#  'satisfaction',
#  'of',
#  'the',
#  'remaining',
#  'regulatory',
#  'condition',
#  'for',
#  'tender',
#  'offerstitch',
#  'fix',
#  'ceo',
#  'says',
#  'the',
#  'online',
#  'styling',
#  'company',
#  'could',
#  'feel',
#  'potential',
#  'tariffsexclusive:',
#  'regulators',
#  'weigh',
#  "'startle",
#  "factors'",
#  'for',
#  'boeing',
#  '737',
#  'max',
#  'pilot',
#  'training',
#  'transport',
#  'canada',
#  'executiveapple',
#  'announces',
#  'free',
#  'repair',
#  'program',
#  'for',
#  'some',
#  'iphone',
#  '6s',
#  'devices',
#  'that',
#  'might',
#  'not',
#  'turn',
#  'onfinal',
#  'trade:',
#  'aapl',
#  'pfpt',
#  'kbe',
#  '&',
#  'cmecigna',
#  '(ci)',
#  'outpaces',
#  'stock',
#  'market',
#  'gains:',
#  'what',
#  'you',
#  'should',
#  'knowyext:',
#  'investment',
#  'is',
#  'a',
#  'bargain',
#  'at',
#  'current',
#  'valuationapellis',
#  'pharmaceuticals',
#  'announces',
#  'inducement',
#  'grants',
#  'under',
#  'nasdaq',
#  'listing',
#  'rule',
#  '5635(c)(4)',
#  'what',
#  'tesla’s',
#  'grab',
#  'of',
#  'deepscale',
#  'is',
#  'all',
#  'aboutbp',
#  'ceo',
#  'bob',
#  'dudley',
#  'to',
#  'step',
#  'down',
#  'in',
#  'marchles',
#  'camionneurs',
#  'de',
#  'cntl',
#  'affiliés',
#  'à',
#  'unifor',
#  'ratifient',
#  'une',
#  'nouvelle',
#  'convention',
#  'collectiveaeterna',
#  'zentaris',
#  'announces',
#  'appointment',
#  'of',
#  'new',
#  'president',
#  'and',
#  'chief',
#  'executive',
#  'officerpaypal',
#  'pulls',
#  'out',
#  'of',
#  'libra',
#  'facebook’s',
#  'cryptocurrency',
#  'projecth&r',
#  'block',
#  'to',
#  'invest',
#  'in',
#  'kansas',
#  'city',
#  'startup',
#  'community',
#  'through',
#  'kcrise',
#  'fund',
#  "iiapple's",
#  'revenues:',
#  'splinteringmain',
#  'issues',
#  'in',
#  'uaw',
#  'gm',
#  'labor',
#  'talks',
#  'narrow',
#  'to',
#  'wages',
#  'pensions:',
#  'source3',
#  'reasons',
#  'cedar',
#  'fair',
#  'shot',
#  'down',
#  'six',
#  'flagswwe',
#  'friday',
#  'night',
#  'smackdown',
#  'draws',
#  'massive',
#  ...]

# %%
from collections import Counter
neutral_common_words = Counter(word_list_neutral).most_common()

# %%
neutral_common_words
# Out:
# [('on', 2123),
#  ('ceo', 1999),
#  ('earnings', 1962),
#  ('call', 1944),
#  ('results', 1910),
#  ('2019', 1637),
#  ('inc', 1215),
#  ('to', 937),
#  ('q4', 903),
#  ('q3', 817),
#  ('of', 696),
#  ('the', 553),
#  ('in', 507),
#  ('and', 488),
#  ('2020', 415),
#  ('for', 374),
#  ('corporation', 252),
#  ('announces', 227),
#  ('new', 217),
#  ('with', 188),
#  ('a', 186),
#  ('stock', 169),
#  ('its', 169),
#  ('at', 168),
#  ('from', 142),
#  ('should', 138),
#  ('coronavirus', 135),
#  ('what', 130),
#  ('is', 128),
#  ('you', 126),
#  ('q1', 125),
#  ('group', 119),
#  ('q2', 118),
#  ('moves', 116),
#  ('holdings', 110),
#  ('as', 108),
#  ('corp', 105),
#  ('s', 100),
#  ('company', 95),
#  ('0', 94),
#  ('by', 90),
#  ('million', 88),
#  ('will', 87),
#  ('&', 77),
#  ('over', 65),
#  ('therapeutics', 62),
#  ('management', 62),
#  ('energy', 59),
#  ('be', 58),
#  ('financial', 58),
#  ('pharmaceuticals', 58),
#  ('737', 57),
#  ('david', 57),
#  ('mark', 56),
#  ('international', 54),
#  ('offering', 53),
#  ('u', 53),
#  ('max', 52),
#  ('pricing', 51),
#  ('john', 50),
#  ('public', 50),
#  ('first', 50),
#  ('technologies', 50),
#  ('systems', 49),
#  ('covid', 49),
#  ('business', 48),
#  ('technology', 48),
#  ('into', 47),
#  ('5', 46),
#  ('boeing', 45),
#  ('billion', 45),
#  ('says', 44),
#  ("'s", 44),
#  ('ltd', 43),
#  ('market', 42),
#  ('down', 42),
#  ('health', 42),
#  ('after', 41),
#  ('medical', 41),
#  ('all', 40),
#  ('value', 40),
#  ('amid', 40),
#  ('provides', 40),
#  ('data', 39),
#  ('global', 39),
#  ('about', 39),
#  ('talks', 39),
#  ('reports', 39),
#  ('due', 38),
#  ('production', 38),
#  ('capital', 38),
#  ('michael', 38),
#  ('19', 38),
#  ('common', 37),
#  ('investors', 37),
#  ('investment', 37),
#  ('pay', 37),
#  ('annual', 36),
#  ('vs', 35),
#  ('1', 35),
#  ('next', 35),
#  ('steve', 35),
#  ('transcriptthe', 35),
#  ('plc', 35),
#  ('000', 34),
#  ('year', 34),
#  ('time', 34),
#  ('has', 34),
#  ('limited', 34),
#  ('not', 33),
#  ('top', 33),
#  ('china', 33),
#  ('3', 33),
#  ('quarter', 32),
#  ('but', 32),
#  ('growth', 32),
#  ('airlines', 32),
#  ('dividend', 31),
#  ('are', 31),
#  ('senior', 31),
#  ('scott', 31),
#  ('workers', 30),
#  ('board', 30),
#  ('one', 29),
#  ('co', 29),
#  ('mike', 29),
#  ('long', 29),
#  ('asset', 28),
#  ('it', 28),
#  ('more', 28),
#  ('home', 28),
#  ('services', 28),
#  ('acquisition', 28),
#  ('electric', 27),
#  ('jim', 27),
#  ('industries', 27),
#  ('jeff', 27),
#  ('update', 26),
#  ('cash', 26),
#  ('$1', 26),
#  ('incorporated', 26),
#  ('which', 25),
#  ('partners', 25),
#  ('that', 25),
#  ('term', 25),
#  ('pharma', 25),
#  ('james', 25),
#  ('kevin', 25),
#  ('up', 24),
#  ('us', 24),
#  ('close', 24),
#  ('2', 24),
#  ('or', 24),
#  ('sales', 24),
#  ('tom', 24),
#  ('gold', 24),
#  ('tesla', 24),
#  ('prices', 23),
#  ('unveils', 23),
#  ('two', 23),
#  ('healthcare', 23),
#  ('employees', 23),
#  ('trust', 23),
#  ('etf', 23),
#  ('companies', 23),
#  ('brian', 23),
#  ('chris', 23),
#  ('dan', 23),
#  ('oil', 22),
#  ('off', 22),
#  ('mobile', 22),
#  ('power', 22),
#  ('bank', 22),
#  ('help', 22),
#  ('future', 22),
#  ('media', 22),
#  ('brands', 22),
#  ('joseph', 22),
#  ('microsoft', 22),
#  ('solutions', 22),
#  ('greg', 22),
#  ('plan', 21),
#  ('quarterly', 21),
#  ('test', 21),
#  ('cut', 21),
#  ('realty', 21),
#  ('4', 21),
#  ('notes', 21),
#  ('take', 21),
#  ('software', 21),
#  ('than', 21),
#  ('american', 21),
#  ('robert', 21),
#  ('shares', 20),
#  ('may', 20),
#  ('tim', 20),
#  ('apple', 20),
#  ('have', 20),
#  ('york', 20),
#  ('flight', 20),
#  ('against', 20),
#  ('fda', 20),
#  ('conference', 20),
#  ('johnson', 19),
#  ('bancorp', 19),
#  ('sale', 19),
#  ('some', 19),
#  ('fourth', 19),
#  ('tech', 19),
#  ('california', 19),
#  ('bob', 19),
#  ('record', 19),
#  ('sell', 19),
#  ('bill', 19),
#  ('back', 19),
#  ('stores', 19),
#  ('how', 19),
#  ('george', 19),
#  ('paul', 19),
#  ('resources', 19),
#  ('files', 19),
#  ('trial', 18),
#  ('better', 18),
#  ('retail', 18),
#  ('under', 18),
#  ('chief', 18),
#  ('digital', 18),
#  ('during', 18),
#  ('peter', 18),
#  ('richard', 18),
#  ('latest', 17),
#  ('third', 17),
#  ('phase', 17),
#  ('general', 17),
#  ('declares', 17),
#  ('full', 17),
#  ('other', 17),
#  ('opens', 17),
#  ('buy:', 17),
#  ('de', 17),
#  ('out', 17),
#  ('through', 17),
#  ('closing', 17),
#  ('union', 17),
#  ('cloud', 17),
#  ('launches', 17),
#  ('report', 17),
#  ('strong', 17),
#  ('drug', 17),
#  ('rob', 17),
#  ('service', 17),
#  ('model', 17),
#  ('revenue', 16),
#  ('store', 16),
#  ('gary', 16),
#  ('announce', 16),
#  ('need', 16),
#  ('nasdaq', 16),
#  ('auto', 16),
#  ('netflix', 16),
#  ('big', 16),
#  ('—', 16),
#  ('jack', 16),
#  ('5g', 16),
#  ('work', 16),
#  ('anderson', 16),
#  ('eric', 16),
#  ('net', 16),
#  ('price', 16),
#  ('biosciences', 16),
#  ('can', 16),
#  ('suspend', 16),
#  ('fund', 15),
#  ('an', 15),
#  ('good', 15),
#  ('fiscal', 15),
#  ('plans', 15),
#  ('free', 15),
#  ('receives', 15),
#  ('uber', 15),
#  ('open', 15),
#  ('google', 15),
#  ('networks', 15),
#  ('cuts', 15),
#  ('investor', 15),
#  ('e', 15),
#  ('sciences', 15),
#  ('offer', 15),
#  ('resorts', 15),
#  ('launch', 15),
#  ('key', 14),
#  ('support', 14),
#  ('holding', 14),
#  ('hit', 14),
#  ('street', 14),
#  ('major', 14),
#  ('streaming', 14),
#  ('beyond', 14),
#  ('no', 14),
#  ('merger', 14),
#  ('could', 14),
#  ('week', 14),
#  ('their', 14),
#  ('balance', 14),
#  ('care', 14),
#  ('best', 14),
#  ('trade', 14),
#  ('before', 14),
#  ('cannabis', 14),
#  ('get', 14),
#  ('court', 14),
#  ('delivery', 14),
#  ('keith', 14),
#  ('short', 14),
#  ('response', 14),
#  ('information', 14),
#  ('dave', 14),
#  ('communications', 14),
#  ('contract', 14),
#  ('day', 14),
#  ("corporation's", 14),
#  ('p', 14),
#  ('berkshire', 14),
#  ('20', 14),
#  ('stake', 14),
#  ('transcripttesla', 14),
#  ('related', 14),
#  ('shareholder', 14),
#  ('approval', 14),
#  ('wall', 13),
#  ('research', 13),
#  ('clinical', 13),
#  ('national', 13),
#  ('6', 13),
#  ('looks', 13),
#  ('online', 13),
#  ('potential', 13),
#  ('canada', 13),
#  ('listing', 13),
#  ('startup', 13),
#  ('high', 13),
#  ('agreement', 13),
#  ('calls', 13),
#  ('operations', 13),
#  ('j', 13),
#  ('look', 13),
#  ('demand', 13),
#  ('cramer', 13),
#  ('amazon', 13),
#  ('v', 13),
#  ('joe', 13),
#  ('presents', 13),
#  ('america', 13),
#  ('dr', 13),
#  ('share', 13),
#  ('lake', 12),
#  ('app', 12),
#  ('com', 12),
#  ('t', 12),
#  ('much', 12),
#  ('outlook', 12),
#  ('n', 12),
#  ('grants', 12),
#  ('just', 12),
#  ('strike', 12),
#  ('jobs', 12),
#  ('takes', 12),
#  ('food', 12),
#  ('supply', 12),
#  ('continues', 12),
#  ('credit', 12),
#  ('another', 12),
#  ('end', 12),
#  ('small', 12),
#  ('additional', 12),
#  ("won't", 12),
#  ('reach', 12),
#  ('despite', 12),
#  ('provide', 12),
#  ('products', 12),
#  ('right', 12),
#  ('investing', 12),
#  ('raise', 12),
#  ('face', 12),
#  ('restaurants', 12),
#  ('enterprises', 12),
#  ('todd', 12),
#  ('air', 12),
#  ('lp', 12),
#  ('properties', 12),
#  ('around', 12),
#  ('go', 12),
#  ('pot', 12),
#  ('ahead', 11),
#  ('martin', 11),
#  ('7', 11),
#  ('inducement', 11),
#  ('rule', 11),
#  ('network', 11),
#  ('profit', 11),
#  ('class', 11),
#  ('charles', 11),
#  ('yield', 11),
#  ('most', 11),
#  ('government', 11),
#  ('jay', 11),
#  ('build', 11),
#  ('backed', 11),
#  ('low', 11),
#  ('acquire', 11),
#  ('names', 11),
#  ('way', 11),
#  ('patrick', 11),
#  ('they', 11),
#  ('closes', 11),
#  ('bruce', 11),
#  ('factory', 11),
#  ('car', 11),
#  ('impact', 11),
#  ('industry', 11),
#  ('s&p', 11),
#  ('starting', 11),
#  ('ron', 11),
#  ('l', 11),
#  ('pat', 11),
#  ('development', 11),
#  ('500', 11),
#  ('suspends', 11),
#  ('further', 11),
#  ('ces', 11),
#  ('temporarily', 11),
#  ('libra', 10),
#  ('meeting', 10),
#  ("tesla's", 10),
#  ('safety', 10),
#  ('watch', 10),
#  ('house', 10),
#  ('zuckerberg', 10),
#  ('platform', 10),
#  ('marc', 10),
#  ('step', 10),
#  ('plus', 10),
#  ('softbank', 10),
#  ('pg&e', 10),
#  ('depot', 10),
#  ('life', 10),
#  ('rival', 10),
#  ('debt', 10),
#  ('steps', 10),
#  ('gets', 10),
#  ('chairman', 10),
#  ('water', 10),
#  ('chinese', 10),
#  ('show', 10),
#  ('morgan', 10),
#  ('van', 10),
#  ('positive', 10),
#  ('money', 10),
#  ('customers', 10),
#  ('gates', 10),
#  ("group's", 10),
#  ('–', 10),
#  ('facebook', 10),
#  ('meat', 10),
#  ('miller', 10),
#  ('andrew', 10),
#  ('doug', 10),
#  ('midstream', 10),
#  ('unaudited', 10),
#  ('8', 10),
#  ('weekly:', 10),
#  ('labs', 10),
#  ('virus', 10),
#  ('looking', 9),
#  ('portfolio', 9),
#  ("facebook's", 9),
#  ('journal:', 9),
#  ('india', 9),
#  ('bath', 9),
#  ('cook', 9),
#  ('motors', 9),
#  ('seeks', 9),
#  ('sprint', 9),
#  ('series', 9),
#  ('completes', 9),
#  ('9', 9),
#  ('$100', 9),
#  ('say', 9),
#  ('know', 9),
#  ('trade:', 9),
#  ('president', 9),
#  ('uaw', 9),
#  ('gm', 9),
#  ('reasons', 9),
#  ('bad', 9),
#  ('use', 9),
#  ('this', 9),
#  ('gas', 9),
#  ('treatment', 9),
#  ('restaurant', 9),
#  ('rejects', 9),
#  ('break', 9),
#  ('insurance', 9),
#  ('set', 9),
#  ('driving', 9),
#  ('mac', 9),
#  ('guidance', 9),
#  ('solar', 9),
#  ('tv', 9),
#  ('become', 9),
#  ('world', 9),
#  ('nvidia', 9),
#  ('last', 9),
#  ('partner', 9),
#  ('tax', 9),
#  ('trading', 9),
#  ('stop', 9),
#  ('times', 9),
#  ('private', 9),
#  ('convertible', 9),
#  ('per', 9),
#  ('least', 9),
#  ('offers', 9),
#  ('line', 9),
#  ('jet', 9),
#  ('cap', 9),
#  ('lee', 9),
#  ('ag', 9),
#  ('ted', 9),
#  ('transcriptmicrosoft', 9),
#  ('half', 9),
#  ("holdings'", 9),
#  ('does', 9),
#  ('barry', 9),
#  ('social', 9),
#  ('we', 9),
#  ('rise', 9),
#  ('brown', 9),
#  ('extension', 9),
#  ('worldwide', 9),
#  ('sheet', 9),
#  ('coverage', 9),
#  ('ratios', 9),
#  ('rich', 9),
#  ('mortgage', 9),
#  ('matt', 9),
#  ('hospitality', 9),
#  ('purchase', 9),
#  ('biopharma', 9),
#  ('approves', 9),
#  ('bond', 9),
#  ('davidson', 9),
#  ('hathaway', 9),
#  ('nearly', 9),
#  ('bid', 9),
#  ('our', 9),
#  ('expect', 9),
#  ('income', 9),
#  ('etf:', 9),
#  ('shanghai', 9),
#  ('if', 9),
#  ('777x', 9),
#  ('form', 9),
#  ('withdraws', 9),
#  ('flights', 9),
#  ('fix', 8),
#  ('sachs', 8),
#  ('united', 8),
#  ('reportedly', 8),
#  ('outlet', 8),
#  ('earnings:', 8),
#  ('action', 8),
#  ('present', 8),
#  ('transcriptamazon', 8),
#  ('orders', 8),
#  ('joins', 8),
#  ('release', 8),
#  ('i', 8),
#  ('thousands', 8),
#  ('filing', 8),
#  ('program', 8),
#  ('bargain', 8),
#  ('executive', 8),
#  ('block', 8),
#  ('recent', 8),
#  ('banks', 8),
#  ('state', 8),
#  ('own', 8),
#  ('people', 8),
#  ('starliner', 8),
#  ('space', 8),
#  ('finds', 8),
#  ('sean', 8),
#  ('shows', 8),
#  (':', 8),
#  ('b', 8),
#  ('meet', 8),
#  ('growing', 8),
#  ('must', 8),
#  ('31', 8),
#  ('payments', 8),
#  ('goldman', 8),
#  ('who', 8),
#  ('steel', 8),
#  ('gaming', 8),
#  ('appoints', 8),
#  ("'", 8),
#  ('transcriptboeing', 8),
#  ('ken', 8),
#  ('settlement', 8),
#  ('order', 8),
#  ('funds', 8),
#  ('brand', 8),
#  ('make', 8),
#  ('$2', 8),
#  ('sa', 8),
#  ('exec', 8),
#  ('douglas', 8),
#  ('jeffrey', 8),
#  ('william', 8),
#  ('travel', 8),
#  ('brad', 8),
#  ('selling', 8),
#  ('wins', 8),
#  ('strategy', 8),
#  ('date', 8),
#  ('genetics', 8),
#  ('property', 8),
#  ('like', 8),
#  ('lawsuit', 8),
#  ('these', 8),
#  ('anthony', 8),
#  ('finance', 8),
#  ('jason', 8),
#  ("international's", 8),
#  ('steven', 8),
#  ('murphy', 8),
#  ('ceo:', 8),
#  ('jon', 8),
#  ('10', 8),
#  ("buffett's", 8),
#  ('december', 8),
#  ('vehicles', 8),
#  ('join', 8),
#  ('political', 8),
#  ('musk', 8),
#  ('buy', 8),
#  ('signs', 8),
#  ('fred', 8),
#  ('see', 8),
#  ('expects', 8),
#  ('direct', 8),
#  ('unit', 8),
#  ('club', 8),
#  ('fight', 8),
#  ('march', 8),
#  ('avoid', 7),
#  ("technologies'", 7),
#  ('$10', 7),
#  ('ryan', 7),
#  ('mary', 7),
#  ('coming', 7),
#  ('transcriptfacebook', 7),
#  ('wants', 7),
#  ('staff', 7),
#  ('three', 7),
#  ('change', 7),
#  ('november', 7),
#  ('increases', 7),
#  ('proposed', 7),
#  ('customer', 7),
#  ('iphone', 7),
#  ('city', 7),
#  ('fair', 7),
#  ('massive', 7),
#  ('fox', 7),
#  ('re', 7),
#  ('local', 7),
#  ('expectations', 7),
#  ('expands', 7),
#  ('cheap', 7),
#  ('notice', 7),
#  ('sportswear', 7),
#  ('pushes', 7),
#  ('going', 7),
#  ('risk', 7),
#  ('security', 7),
#  ('petroleum', 7),
#  ('200', 7),
#  ('rates', 7),
#  ('cars', 7),
#  ('rate', 7),
#  ('11', 7),
#  ('self', 7),
#  ('finally', 7),
#  ('lead', 7),
#  ('flying', 7),
#  ('stephen', 7),
#  ('australian', 7),
#  ('testing', 7),
#  ('therapy', 7),
#  ('final', 7),
#  ('wework', 7),
#  ('tests', 7),
#  ('early', 7),
#  ('things', 7),
#  ('corporate', 7),
#  ('myers', 7),
#  ('jones', 7),
#  ('product', 7),
#  ('expansion', 7),
#  ('pacific', 7),
#  ('island', 7),
#  ('transcriptunited', 7),
#  ('preliminary', 7),
#  ('commercial', 7),
#  ('news', 7),
#  ('non', 7),
#  ('logistics', 7),
#  ('total', 7),
#  ('because', 7),
#  ('game', 7),
#  ('tells', 7),
#  ('pharmaceutical', 7),
#  ('daniel', 7),
#  ('system', 7),
#  ('fuel', 7),
#  ('personal', 7),
#  ('chip', 7),
#  ('jedi', 7),
#  ('less', 7),
#  ('when', 7),
#  ('turnaround', 7),
#  ('many', 7),
#  ('cancer', 7),
#  ('sells', 7),
#  ('communities', 7),
#  ('ford', 7),
#  ('real', 7),
#  ('christopher', 7),
#  ('frank', 7),
#  ('chrysler', 7),
#  ('entertainment', 7),
#  ('office', 7),
#  ('thomas', 7),
#  ('between', 7),
#  ('dennis', 7),
#  ('higher', 7),
#  ("pharmaceuticals'", 7),
#  ('ex', 7),
#  ('january', 7),
#  ('materials', 7),
#  ('markets', 7),
#  ('fargo', 7),
#  ('cola', 7),
#  ('premium', 7),
#  ('50', 7),
#  ('westpac', 7),
#  ('leave', 7),
#  ('behind', 7),
#  ('twitter', 7),
#  ('content', 7),
#  ('letter', 7),
#  ('lyft', 7),
#  ('preferred', 7),
#  ('four', 7),
#  ('gains', 7),
#  ('coffee', 7),
#  ('masks', 7),
#  ('asia', 6),
#  ('federal', 6),
#  ('worth', 6),
#  ('education', 6),
#  ('giant', 6),
#  ('interest', 6),
#  ('joint', 6),
#  ('expensive', 6),
#  ('regulatory', 6),
#  ('grows', 6),
#  ('airbus', 6),
#  ('dispute', 6),
#  ('trump', 6),
#  ('benioff', 6),
#  ('employee', 6),
#  ('microelectronics', 6),
#  ('natural', 6),
#  ('f', 6),
#  ('using', 6),
#  ('innovation', 6),
#  ('southern', 6),
#  ('black', 6),
#  ('tender', 6),
#  ('might', 6),
#  ('current', 6),
#  ('appointment', 6),
#  ('pulls', 6),
#  ('invest', 6),
#  ('issues', 6),
#  ('coca', 6),
#  ('rock', 6),
#  ('seattle', 6),
#  ('largest', 6),
#  ('near', 6),
#  ('so', 6),
#  ('bigger', 6),
#  ('financing', 6),
#  ('patent', 6),
#  ('deliver', 6),
#  ('flat', 6),
#  ('del', 6),
#  ('decision', 6),
#  ('expected', 6),
#  ('team', 6),
#  ('cfo', 6),
#  ('confirms', 6),
#  ('boeing’s', 6),
#  ('news:', 6),
#  ('review', 6),
#  ('gene', 6),
#  ('produce', 6),
#  ('bounce', 6),
#  ('parent', 6),
#  ('highs', 6),
#  ('upcoming', 6),
#  ('needs', 6),
#  ('project', 6),
#  ('soon', 6),
#  ('cost', 6),
#  ('reed', 6),
#  ('states', 6),
#  ('surgical', 6),
#  ('edward', 6),
#  ('officer', 6),
#  ('bancshares', 6),
#  ('transcriptapple', 6),
#  ('kelly', 6),
#  ('dollar', 6),
#  ('defense', 6),
#  ('ever', 6),
#  ('crisis', 6),
#  ('cell', 6),
#  ('ready', 6),
#  ('worst', 6),
#  ('losing', 6),
#  ('access', 6),
#  ('usa', 6),
#  ('instruments', 6),
#  ('vegas', 6),
#  ('even', 6),
#  ('investments', 6),
#  ('west', 6),
#  ('interim', 6),
#  ('relationship', 6),
#  ('simon', 6),
#  ('begins', 6),
#  ('any', 6),
#  ('pichai', 6),
#  ('alphabet', 6),
#  ('losses', 6),
#  ('stay', 6),
#  ('estate', 6),
#  ("therapeutics'", 6),
#  ('stuart', 6),
#  ('c', 6),
#  ('aaron', 6),
#  ('darren', 6),
#  ('green', 6),
#  ('wang', 6),
#  ('grant', 6),
#  ('tony', 6),
#  ('transcripthow', 6),
#  ('mlp/midstream', 6),
#  ('distributions', 6),
#  ('electronics', 6),
#  ('faces', 6),
#  ('glenn', 6),
#  ('pipeline', 6),
#  ('howard', 6),
#  ('chad', 6),
#  ('matthew', 6),
#  ('adam', 6),
#  ('rick', 6),
#  ('across', 6),
#  ('biotech', 6),
#  ('diagnostics', 6),
#  ('focus', 6),
#  ('super', 6),
#  ('hong', 6),
#  ('stocks', 6),
#  ('post', 6),
#  ('summit', 6),
#  ('marijuana', 6),
#  ('takeover', 6),
#  ('keeps', 6),
#  ('pentagon', 6),
#  ('levels', 6),
#  ('generation', 6),
#  ('suv', 6),
#  ('warehouse', 6),
#  ('plant', 6),
#  ('cybertruck', 6),
#  ('cutting', 6),
#  ('plane', 6),
#  ('music', 6),
#  ('users', 6),
#  ('loan', 6),
#  ('possible', 6),
#  ('directors', 6),
#  ('point', 6),
#  ('buyback', 6),
#  ('suisse', 6),
#  ('sony', 6),
#  ('transcriptamerican', 6),
#  ('furlough', 6),
#  ('warren', 6),
#  ('$0', 6),
#  ('valuation', 6),
#  ('return', 6),
#  ('maiden', 6),
#  ('video', 6),
#  ("don't", 6),
#  ('worker', 6),
#  ('only', 6),
#  ('wifi', 6),
#  ('commits', 6),
#  ('vaccine', 6),
#  ('storage', 6),
#  ('donate', 6),
#  ('leadership', 5),
#  ('kim', 5),
#  ('ohio', 5),
#  ('opioid', 5),
#  ('getting', 5),
#  ('(pypl)', 5),
#  ('square', 5),
#  ('participate', 5),
#  ('venture', 5),
#  ('society', 5),
#  ('slow', 5),
#  ('connection', 5),
#  ('consumer', 5),
#  ('second', 5),
#  ('his', 5),
#  ('layoffs', 5),
#  ('part', 5),
#  ('reduce', 5),
#  ('live', 5),
#  ('definitive', 5),
#  ('statement', 5),
#  ('been', 5),
#  ('volatility', 5),
#  ('sector', 5),
#  ('pilot', 5),
#  ('devices', 5),
#  ('gains:', 5),
#  ('community', 5),
#  ('labor', 5),
#  ('six', 5),
#  ('gap', 5),
#  ('days', 5),
#  ('renewable', 5),
#  ('well', 5),
#  ('expand', 5),
#  ('express', 5),
#  ('fast', 5),
#  ('prompts', 5),
#  ('industrial', 5),
#  ('among', 5),
#  ('transfer', 5),
#  ('phone', 5),
#  ('accelerate', 5),
#  ('wars:', 5),
#  ('desk', 5),
#  ('aeroportuario', 5),
#  ('pacifico', 5),
#  ('regarding', 5),
#  ('door', 5),
#  ('reorganization', 5),
#  ('force', 5),
#  ('bankruptcy', 5),
#  ('lays', 5),
#  ('privacy', 5),
#  ('stepping', 5),
#  ('urges', 5),
#  ('boss', 5),
#  ('develop', 5),
#  ('equity', 5),
#  ('still', 5),
#  ('fisher', 5),
#  ('limits', 5),
#  ('biotechnologies', 5),
#  ('wet', 5),
#  ('amd', 5),
#  ('sets', 5),
#  ('away', 5),
#  ('control', 5),
#  ('critical', 5),
#  ('blood', 5),
#  ('enters', 5),
#  ('preview:', 5),
#  ...]

# %%
# Cleaning text and lower casing all words
for char in '-.,\n':
    Pos_Text=Pos_Text.replace(char,' ')
Pos_Text = Pos_Text.lower()
# split returns a list of words delimited by sequences of whitespace (including tabs, newlines, etc, like re's \s) 
word_list_Pos = Pos_Text.split()
pos_common_words = Counter(word_list_Pos).most_common()

# %%
df_sentiment = pd.DataFrame(neutral_common_words)
df_sentiment['predicted_labels'] = "Neutral"
df_sentiment
# Out:
#                       0     1 predicted_labels
# 0                    on  2123          Neutral
# 1                   ceo  1999          Neutral
# 2              earnings  1962          Neutral
# 3                  call  1944          Neutral
# 4               results  1910          Neutral
# ...                 ...   ...              ...
# 13988            facial     1          Neutral
# 13989                ‘a     1          Neutral
# 13990  breakthrough’fox     1          Neutral
# 13991        cushionair     1          Neutral
# 13992           canada:     1          Neutral
#
# [13993 rows x 3 columns]

# %%
# df1 = pd.DataFrame(common_words)

# %%
# df1.to_csv("Resources/pre_covid_word_counter.csv")
