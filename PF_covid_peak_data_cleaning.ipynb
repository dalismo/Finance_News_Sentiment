# %%
from functions import *

# %%
x = "Resources/PREDICTIONS_covid_peak_to_slowdown_lr_model.csv"
y = "Resources/covid_peak_to_slow_down_articles_dates.csv"
z = "Resources/Tickers_Nested_covid_peak_to_slow_down_.csv"
w = "Resources/stock_list_tableau.csv"
covid_peak_df = clean_tableau(x, y, z, w)
# Out:
# /Users/paulfeliciano/Desktop/Finance_News_Sentiment/functions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flattened_df1["keywords_clean"] = flattened_df1["keywords"].map(lambda j: re.sub(r'\W+', '', j))
# /Users/paulfeliciano/Desktop/Finance_News_Sentiment/functions.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precovid_tableau1["keywords"] = precovid_tableau1["keywords"].str.lower()

# %%
covid_peak_df
# Out:
#      Exchange tickers                                      Name  \
# 0      NASDAQ    AAPL                   Apple Inc. Common Stock
# 0      NASDAQ    AAPL                   Apple Inc. Common Stock
# 0      NASDAQ    AAPL                   Apple Inc. Common Stock
# 0      NASDAQ    AAPL                   Apple Inc. Common Stock
# 0      NASDAQ    AAPL                   Apple Inc. Common Stock
# ...       ...     ...                                       ...
# 3164     NYSE     WBK  Westpac Banking Corporation Common Stock
# 3165     NYSE     WBK  Westpac Banking Corporation Common Stock
# 3165     NYSE     WBK  Westpac Banking Corporation Common Stock
# 3165     NYSE     WBK  Westpac Banking Corporation Common Stock
# 3165     NYSE     WBK  Westpac Banking Corporation Common Stock
#
#             Country      Sector                Industry  \
# 0     United States  Technology  Computer Manufacturing
# 0     United States  Technology  Computer Manufacturing
# ...

# %%
covid_peak_df.to_csv("Resources/2_covid_peak_Tableau.csv")
