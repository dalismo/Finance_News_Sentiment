# %%
from functions import *

# %%
x = "Resources/PREDICTIONS_delta_emerg_to_now_lr_model.csv"
y = "Resources/delta_emergence_till_now_articles_dates.csv"
z = "Resources/Tickers_Nested_delta_emerge_to_now.csv"
w = "Resources/stock_list_tableau.csv"
text_df = clean_tableau(x, y, z, w)
# Out:
# C:\Users\dri90\Finance_News_Sentiment\functions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flattened_df1["keywords_clean"] = flattened_df1["keywords"].map(lambda j: re.sub(r'\W+', '', j))
# C:\Users\dri90\Finance_News_Sentiment\functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precovid_tableau1["keywords"] = precovid_tableau1["keywords"].str.lower()

# %%
text_df
# Out:
#      Exchange tickers                                       Name  \
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# ...       ...     ...                                        ...
# 2904     AMEX     WTT  Wireless Telecom Group  Inc. Common Stock
# 2904     AMEX     WTT  Wireless Telecom Group  Inc. Common Stock
# 2904     AMEX     WTT  Wireless Telecom Group  Inc. Common Stock
# 2904     AMEX     WTT  Wireless Telecom Group  Inc. Common Stock
# 2904     AMEX     WTT  Wireless Telecom Group  Inc. Common Stock
#
#             Country          Sector                       Industry  \
# 0     United States  Transportation  Air Freight/Delivery Services
# 0     United States  Transportation  Air Freight/Delivery Services
# 0     United States  Transportation  Air Freight/Delivery Services
# 0     United States  Transportation  Air Freight/Delivery Services
# 0     United States  Transportation  Air Freight/Delivery Services
# ...             ...             ...                            ...
# 2904  United States   Capital Goods   Telecommunications Equipment
# 2904  United States   Capital Goods   Telecommunications Equipment
# 2904  United States   Capital Goods   Telecommunications Equipment
# 2904  United States   Capital Goods   Telecommunications Equipment
# 2904  United States   Capital Goods   Telecommunications Equipment
#
#                                                    text predicted_label  \
# 0     American Airlines cancels hundreds of flights ...         Neutral
# 0     American Airlines cancels hundreds of flights ...         Neutral
# 0     American Airlines cancels hundreds of flights ...         Neutral
# 0     American Airlines cancels hundreds of flights ...         Neutral
# 0     American Airlines cancels hundreds of flights ...         Neutral
# ...                                                 ...             ...
# 2904  Wireless Telecom Group Announces Preliminary 2...         Neutral
# 2904  Wireless Telecom Group Announces Preliminary 2...         Neutral
# 2904  Wireless Telecom Group Announces Preliminary 2...         Neutral
# 2904  Wireless Telecom Group Announces Preliminary 2...         Neutral
# 2904  Wireless Telecom Group Announces Preliminary 2...         Neutral
#
#             date        keywords
# 0     06/20/2021        american
# 0     06/20/2021        airlines
# 0     06/20/2021         cancels
# 0     06/20/2021        hundreds
# 0     06/20/2021         flights
# ...          ...             ...
# 2904  07/21/2021       announces
# 2904  07/21/2021     preliminary
# 2904  07/21/2021  second-quarter
# 2904  07/21/2021       financial
# 2904  07/21/2021         results
#
# [28408 rows x 10 columns]

# %%
text_df.to_csv("Resources/5_delta_emergence_to_now_Tableau.csv")
