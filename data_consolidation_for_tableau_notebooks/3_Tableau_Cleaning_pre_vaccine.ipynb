# %%
from functions import *

# %%
x = "Resources/PREDICTIONS_pre_vaccine_lr_model.csv"
y = "Resources/pre_vaccine_articles_dates.csv"
z = "Resources/Tickers_Nested_pre_vaccine_.csv"
w = "Resources/stock_list_tableau.csv"
text_df = clean_tableau(x, y, z, w)
# Out:
# C:\Users\dri90\Finance_News_Sentiment\functions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flattened_df1["keywords_clean"] = flattened_df1["keywords"].map(lambda j: re.sub(r'\W+', '', j))
# C:\Users\dri90\Finance_News_Sentiment\functions.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precovid_tableau1["keywords"] = precovid_tableau1["keywords"].str.lower()

# %%
text_df
# Out:
#      Exchange tickers                                       Name  \
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# 0      NASDAQ     AAL  American Airlines Group Inc. Common Stock
# ...       ...     ...                                        ...
# 3713     AMEX    YCBD                    cbdMD Inc. Common Stock
# 3713     AMEX    YCBD                    cbdMD Inc. Common Stock
# 3713     AMEX    YCBD                    cbdMD Inc. Common Stock
# 3713     AMEX    YCBD                    cbdMD Inc. Common Stock
# 3713     AMEX    YCBD                    cbdMD Inc. Common Stock
#
#             Country          Sector  \
# 0     United States  Transportation
# 0     United States  Transportation
# 0     United States  Transportation
# ...

# %%
# text_df.to_csv("Resources/3_pre_vaccine_Tableau.csv")
