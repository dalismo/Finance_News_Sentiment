# %%
from functions import *

# %%
x = "Resources/PREDICTIONS_post_vaccine_lr_model.csv"
y = "Resources/post_vaccine_articles_dates.csv"
z = "Resources/Tickers_Nested_post_vaccine_.csv"
w = "Resources/stock_list_tableau.csv"
text_df = clean_tableau(x, y, z, w)
# Out:
# /Users/albertogonzalez/Desktop/Bootcamp/Finance_News_Sentiment/functions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flattened_df1["keywords_clean"] = flattened_df1["keywords"].map(lambda j: re.sub(r'\W+', '', j))
# /Users/albertogonzalez/Desktop/Bootcamp/Finance_News_Sentiment/functions.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precovid_tableau1["keywords"] = precovid_tableau1["keywords"].str.lower()

# %%
text_df
# Out:
#      Exchange tickers                                               Name  \
# 0      NASDAQ    AAPL                            Apple Inc. Common Stock
# 0      NASDAQ    AAPL                            Apple Inc. Common Stock
# 0      NASDAQ    AAPL                            Apple Inc. Common Stock
# 0      NASDAQ    AAPL                            Apple Inc. Common Stock
# 0      NASDAQ    AAPL                            Apple Inc. Common Stock
# ...       ...     ...                                                ...
# 5448     NYSE     SBH  Sally Beauty Holdings Inc. (Name to be changed...
# 5448     NYSE     SBH  Sally Beauty Holdings Inc. (Name to be changed...
# 5448     NYSE     SBH  Sally Beauty Holdings Inc. (Name to be changed...
# 5448     NYSE     SBH  Sally Beauty Holdings Inc. (Name to be changed...
# 5448     NYSE     SBH  Sally Beauty Holdings Inc. (Name to be changed...
#
#             Country         Sector                         Industry  \
# 0     United States     Technology           Computer Manufacturing
# 0     United States     Technology           Computer Manufacturing
# 0     United States     Technology           Computer Manufacturing
# 0     United States     Technology           Computer Manufacturing
# 0     United States     Technology           Computer Manufacturing
# ...             ...            ...                              ...
# 5448  United States  Miscellaneous  Diversified Commercial Services
# 5448  United States  Miscellaneous  Diversified Commercial Services
# 5448  United States  Miscellaneous  Diversified Commercial Services
# 5448  United States  Miscellaneous  Diversified Commercial Services
# 5448  United States  Miscellaneous  Diversified Commercial Services
#
#                                                    text predicted_label  \
# 0     Apple Sued For $200M In EU Over Allegations It...        Negative
# 0     Apple Sued For $200M In EU Over Allegations It...        Negative
# 0     Apple Sued For $200M In EU Over Allegations It...        Negative
# 0     Apple Sued For $200M In EU Over Allegations It...        Negative
# 0     Apple Sued For $200M In EU Over Allegations It...        Negative
# ...                                                 ...             ...
# 5448  Else Nutrition Reports First Quarter 2021 Resu...         Neutral
# 5448  Else Nutrition Reports First Quarter 2021 Resu...         Neutral
# 5448  Else Nutrition Reports First Quarter 2021 Resu...         Neutral
# 5448  Else Nutrition Reports First Quarter 2021 Resu...         Neutral
# 5448  Else Nutrition Reports First Quarter 2021 Resu...         Neutral
#
#             date     keywords
# 0     12/01/2020        apple
# 0     12/01/2020         sued
# 0     12/01/2020        $200m
# 0     12/01/2020           eu
# 0     12/01/2020  allegations
# ...          ...          ...
# 5448  05/31/2021          90%
# 5448  05/31/2021      quarter
# 5448  05/31/2021      quarter
# 5448  05/31/2021      revenue
# 5448  05/31/2021       growth
#
# [54071 rows x 10 columns]

# %%
text_df.to_csv("Resources/post_vaccine_Tableau.csv")
