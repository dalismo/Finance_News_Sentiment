# %%
from functions import *

# %%
x = "Resources/PREDICTIONS_pre_vaccine_lr_model.csv"
y = "Resources/pre_vaccine_articles_dates.csv"
z = "Resources/Tickers_Nested_pre_vaccine_.csv"
w = "Resources/stock_list_tableau.csv"
text_df = clean_tableau(x, y, z, w)
# Out:
# C:\Users\dri90\Finance_News_Sentiment\functions.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flattened_df1["keywords_clean"] = flattened_df1["keywords"].map(lambda j: re.sub(r'\W+', '', j))
# C:\Users\dri90\Finance_News_Sentiment\functions.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precovid_tableau1["keywords"] = precovid_tableau1["keywords"].str.lower()

# %%
text_df
# Out:
#      Exchange tickers                                          Name  \
# 0      NASDAQ    ALTM  Altus Midstream Company Class A Common Stock
# 0      NASDAQ    ALTM  Altus Midstream Company Class A Common Stock
# 0      NASDAQ    ALTM  Altus Midstream Company Class A Common Stock
# 0      NASDAQ    ALTM  Altus Midstream Company Class A Common Stock
# 0      NASDAQ    ALTM  Altus Midstream Company Class A Common Stock
# ...       ...     ...                                           ...
# 4496     NYSE     VFC                 V.F. Corporation Common Stock
# 4496     NYSE     VFC                 V.F. Corporation Common Stock
# 4496     NYSE     VFC                 V.F. Corporation Common Stock
# 4496     NYSE     VFC                 V.F. Corporation Common Stock
# 4496     NYSE     VFC                 V.F. Corporation Common Stock
#
#             Country                 Sector              Industry  \
# 0     United States                 Energy  Oil & Gas Production
# 0     United States                 Energy  Oil & Gas Production
# 0     United States                 Energy  Oil & Gas Production
# 0     United States                 Energy  Oil & Gas Production
# 0     United States                 Energy  Oil & Gas Production
# ...             ...                    ...                   ...
# 4496  United States  Consumer Non-Durables               Apparel
# 4496  United States  Consumer Non-Durables               Apparel
# 4496  United States  Consumer Non-Durables               Apparel
# 4496  United States  Consumer Non-Durables               Apparel
# 4496  United States  Consumer Non-Durables               Apparel
#
#                                                    text predicted_label  \
# 0     Altus Midstream Company (ALTM) CEO Clay Bretch...         Neutral
# 0     Altus Midstream Company (ALTM) CEO Clay Bretch...         Neutral
# 0     Altus Midstream Company (ALTM) CEO Clay Bretch...         Neutral
# 0     Altus Midstream Company (ALTM) CEO Clay Bretch...         Neutral
# 0     Altus Midstream Company (ALTM) CEO Clay Bretch...         Neutral
# ...                                                 ...             ...
# 4496  Corning Incorporated (GLW) Management Presents...         Neutral
# 4496  Corning Incorporated (GLW) Management Presents...         Neutral
# 4496  Corning Incorporated (GLW) Management Presents...         Neutral
# 4496  Corning Incorporated (GLW) Management Presents...         Neutral
# 4496  Corning Incorporated (GLW) Management Presents...         Neutral
#
#             date      keywords
# 0     08/01/2020         altus
# 0     08/01/2020     midstream
# 0     08/01/2020       company
# 0     08/01/2020        (altm)
# 0     08/01/2020           ceo
# ...          ...           ...
# 4496  11/30/2020        annual
# 4496  11/30/2020    technology
# 4496  11/30/2020       virtual
# 4496  11/30/2020    conference
# 4496  11/30/2020  (transcript)
#
# [44708 rows x 10 columns]

# %%
text_df.to_csv("Resources/3_pre_vaccine_Tableau.csv")
